# %% [markdown]
# # Module 2: Hydrostatics

# %% [markdown]
# The exercises in this module range from lecture 4 to lecture 9.

# %%
# !pip install handcalcs -q
# !pip install Pillow -q

# %%
import handcalcs.render
from sympy import symbols, Eq, solve
from math import sqrt,pi, cos, sin, radians,asin,atan,degrees, tan, log10
from PIL import Image

# %% [markdown]
# Global variables:

# %%
# %%render param
# g=9.81 #m/s2
# rho_water=1000 #kg/m3
# rho_Hg=13600 #kg/m3
# p_atm=101325 #Pa
# Out:
# \[
# \begin{aligned}
# g &= 9.810 \; \;\textrm{(m/s2)}
#  &\rho_{water} &= 1000 \; \;\textrm{(kg/m3)}
#  &\rho_{Hg} &= 13600 \; \;\textrm{(kg/m3)}
# \\[10pt]
#  p_{atm} &= 101325 \; \;\textrm{(Pa)}
# \end{aligned}
# \]

# %% [markdown]
# ## Problems for Lecture 4: Introduction to Hydrostatics

# %% [markdown]
# ### Absolute Pressure, Gauge Pressure and Pressure  Head

# %% [markdown]
# ---
# #### Question 1 (*)[R]

# %% [markdown]
# The weather report states that the current atmospheric pressure is 970 mbar.
# a) Express the pressure as an absolute pressure measured in Pa. {97 kPa}
# b) Express the pressure as an absolute pressure head of water. {9.89 m}
# c) Express the pressure as a absolute pressure head of mercury (assume the density of mercury to be 13 600 kg/m<sup>3</sup>). {0.73 m}

# %% [markdown]
# **Given:**

# %%
# %%render param
# p_mbar=970 #mbar
# Out:
# \[
# \begin{aligned}
# p_{mbar} &= 970 \; \;\textrm{(mbar)}
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# Consider the following unit conversions:
#
# $$ p[bar]=p[mbar]*10^{-3}$$
# $$ p[kPa]=p[bar]*100$$
# $$ p[Pa]=p[kPa]*1000$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_bar= p_mbar*10**-3 #bar
# p_kPa= p_bar*100 #kPa
# p_Pa= p_kPa*1000 #Pa
# Out:
# \[
# \begin{aligned}
# p_{bar} &= p_{mbar} \cdot \left( 10 \right) ^{ -3 } \\&= 970 \cdot \left( 10 \right) ^{ -3 } \\&= 0.97 \; \;\textrm{(bar)}\\[10pt]
# \\[10pt]
# p_{kPa} &= p_{bar} \cdot 100 \\&= 0.97 \cdot 100 \\&= 97.00 \; \;\textrm{(kPa)}\\[10pt]
# \\[10pt]
# p_{Pa} &= p_{kPa} \cdot 1000 \\&= 97.00 \cdot 1000 \\&= 97000.00 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The absolute pressure head of water can be calulated as:
#
# $$h=\frac{p}{\rho_{water}*g}$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h_water= p_Pa/(rho_water*g) #m
# Out:
# \[
# \begin{aligned}
# h_{water} &= \frac{ p_{Pa} }{ \rho_{water} \cdot g } \\&= \frac{ 97000.00 }{ 1000 \cdot 9.81 } \\&= 9.89 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# c)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The absolute pressure head of mercury can be calulated as:
#
# $$h=\frac{p}{\rho_{Hg}*g}$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h_Hg= p_Pa/(rho_Hg*g) #m
# Out:
# \[
# \begin{aligned}
# h_{Hg} &= \frac{ p_{Pa} }{ \rho_{Hg} \cdot g } \\&= \frac{ 500000 }{ 13600 \cdot 9.81 } \\&= 3.75 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2(*)

# %% [markdown]
#  If the pressure in a tank is 500 kPa. Find the equivalent pressure head of a) water b) mercury with density 13 600 kg/m<sup>3</sup> and c) heavy fuel oil with a specific gravity of 0.92. {51 m, 3.7 m, 55.4 m}

# %% [markdown]
# **Given:**

# %%
# %%render param
# p=500 #kPa
# rho_Hg_=13600 #kg/m3
# s=0.92
# Out:
# \[
# \begin{aligned}
# p &= 500 \; \;\textrm{(kPa)}
#  &\rho_{Hg_{}} &= 13600 \; \;\textrm{(kg/m3)}
#  &s &= 0.920 \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The equation that relates the presure and height is the following
#
# $$
# p=\rho g h
# $$
#
# Where:
# $p=[Pa], \rho=[kg/m^3], g= [m/s^2], h=[m]$
#
# The specific gravity of a fluid is
#
# $$
# s= \frac {\rho_{liquid}}{\rho_{water}}
# $$
# ```

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The equation that relates the presure and height is the following
#
# $$
# p=\rho g h
# $$
#
# Where:
# $p=[Pa], \rho=[kg/m^3], g= [m/s^2], h=[m]$
#
# Considering the above equation, the units of $p$ should be change from [kPa] to [Pa]
#
# The equation to calculate the height is
#
# $$
# h=\frac{p}{g \rho}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_Pa=p*1000 #Pa
# h_water= p_Pa/(g*rho_water) #m
# Out:
# \[
# \begin{aligned}
# p_{Pa} &= 500000 \; \;\textrm{(Pa)}
# \\[10pt]
# h_{water} &= \frac{ p_{Pa} }{ g \cdot \rho_{water} } \\&= \frac{ 500000 }{ 9.81 \cdot 1000 } \\&= 50.97 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h_Hg= p_Pa/(g*rho_Hg_) #m
# Out:
# \[
# \begin{aligned}
# h_{Hg} &= \frac{ p_{Pa} }{ g \cdot \rho_{Hg_{}} } \\&= \frac{ 500000 }{ 9.81 \cdot 13600 } \\&= 3.75 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# c)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The specific gravity of a fluid is
#
# $$
# s= \frac {\rho_{liquid}}{\rho_{water}}
# $$
#
# By using the equation of specific gravity the $\rho_{oil}$ can be calculated assuming a $ \rho_{water}=1000 kg/m^3$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_oil= s*rho_water #kg/m3
# h_oil= p_Pa/(g*rho_oil) #m
# Out:
# \[
# \begin{aligned}
# \rho_{oil} &= s \cdot \rho_{water} \\&= 0.920 \cdot 1000 \\&= 920.000 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# h_{oil} &= \frac{ p_{Pa} }{ g \cdot \rho_{oil} } \\&= \frac{ 500000 }{ 9.810 \cdot 920.000 } \\&= 55.400 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 3 (**)[R]

# %% [markdown]
# If the atmospheric pressure is 780 mbar and a gauge attached to a tank reads 330 mm Hg vacuum, what is the absolute pressure within the tank? Assume s<sub>Hg</sub> = 13.56. {34 kPa}

# %% [markdown]
# **Given:**

# %%
# %%render param 2
# s_Hg=13.56
# h=330/1000 #m
# p_atm_=78000 #Pa
# Out:
# \[
# \begin{aligned}
# s_{Hg} &= 13.56 \;
#  &h &= 0.33 \; \;\textrm{(m)}
#  &p_{atm_{}} &= 78000 \; \;\textrm{(Pa)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The absolute pressure can be calculated as
#
# $$
# p_{abs}=p_{atm}+p_{gauge}
# $$
#
# $p_{atm}$ is given and $p_{gauge}$ can be calculated as
#
# $$
# p_{gauge}=\gamma \cdot h
# $$
#
# where $h$ is given and $\gamma = \rho_{Hg} \cdot h$
#
# Remember that
#
# $$\rho_{Hg}=s_{Hg} \cdot \rho_{water}$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_Hg= s_Hg*rho_water #kg/m3
# gamma= rho_Hg*g #N/m3
# p_gauge= gamma*h #Pa
# p_abs= p_atm_+(-p_gauge) #Pa
# p_abs_kPa= p_abs/1000 #kPa
# Out:
# \[
# \begin{aligned}
# \rho_{Hg} &= s_{Hg} \cdot \rho_{water} \\&= 13.56 \cdot 1000 \\&= 13560.00 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# \gamma &= \rho_{Hg} \cdot g \\&= 13560.00 \cdot 9.81 \\&= 133023.60 \; \;\textrm{(N/m3)}\\[10pt]
# \\[10pt]
# p_{gauge} &= \gamma \cdot h \\&= 133023.60 \cdot 0.33 \\&= 43897.79 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{abs} &= p_{atm_{}} + \left( - p_{gauge} \right) \\&= 78000 + \left( - 43897.79 \right) \\&= 34102.21 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{abs_{kPa}} &= \frac{ p_{abs} }{ 1000 } \\&= \frac{ 34102.21 }{ 1000 } \\&= 34.10 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 4 (***)

# %% [markdown]
# A pressure gauge is connected to a tank filled with fluid under standard sea level conditions. The gauge shows a reading of 305 kPa. The gauge is then enclosed in a chamber as shown below, and the absolute pressure head in the chamber reduced to 100 mm Hg (the fluid pressure remains unchanged). What will the reading on the pressure gauge now be? {393 kPa}

# %%
from PIL import Image
img = Image.open(r"figures/30.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=758x380>

# %% [markdown]
# **Given:**

# %%
# %%render param
# p_gauge= 305 #kPa
# h_Hg= 100 #mmHg
# Out:
# \[
# \begin{aligned}
# p_{gauge} &= 305 \; \;\textrm{(kPa)}
#  &h_{Hg} &= 100 \; \;\textrm{(mmHg)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The absolute pressure can be calculates as
#
# $$
# p_{abs}= p_{atm}+ p_{gauge}
# $$
#
# The units of the three pressure should be in [Pa]. For that reason, a unit conversion must be done for $p_{gauge}$
#
# The atmosphere now changed to 100 mmHg absolute, so with this a new atmospheric pressure can be calculated. To calculate the pressure in the chamber considering the height of the fluid the following equation should be used: $p_2=\rho g h_{Hg}$ in this equation the units are the following $p=[Pa], \rho=[kg/m^3], g= [m/s^2], h_{Hg}=[m]$
#
# For that reason, a unit conversion must be done for $h_{Hg}$
#
# To calculate the new gauge pressure the following equation should be used
#
# $$
# p_{gauge2}= p_{abs}- p_{atm2}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# p_gauge_Pa= p_gauge*1000 #Pa
# p_abs= p_atm+p_gauge_Pa#Pa
# h_Hg= h_Hg/1000 #m
# p_atm_2= rho_Hg*g*h_Hg #Pa
# p_gauge= p_abs-p_atm_2 #Pa
# Out:
# \[
# \begin{aligned}
# p_{gauge_{Pa}} &= p_{gauge} \cdot 1000 \\&= 392983.4 \cdot 1000 \\&= 305000 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{abs} &= p_{atm} + p_{gauge_{Pa}} \\&= 101325 + 305000 \\&= 406325 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# h_{Hg} &= \frac{ h_{Hg} }{ 1000 } \\&= \frac{ 0.1 }{ 1000 } \\&= 0.1 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# p_{atm_{2}} &= \rho_{Hg} \cdot g \cdot h_{Hg} \\&= 13600 \cdot 9.8 \cdot 0.1 \\&= 13341.6 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{gauge} &= p_{abs} - p_{atm_{2}} \\&= 406325 - 13341.6 \\&= 392983.4 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Pressure Variation in Incompressible Fluids

# %% [markdown]
# ---
# #### Question 5 (*)

# %% [markdown]
# Calculate the gauge and absolute pressures at a depth of 10 m below a water surface under standard sea level conditions. {98.1 kPa, 199.4 kPa}

# %% [markdown]
# **Given:**

# %%
# %%render param
# h= 10 #m
# Out:
# \[
# \begin{aligned}
# h &= 10 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The absolute pressure under standard sea level conditions is 101325 Pa and the gauge pressure can be calculated as
#
# $$
# p_{gauge}=\rho_{water} \cdot g \cdot h
# $$
#
# The absolute pressure can be calculated as $ p_{abs}= p_{atm}+ p_{gauge}$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# p_gauge= rho_water*g*h #Pa
# p_gauge_kPa= p_gauge/1000 #kPa
# p_abs= (p_atm+p_gauge)/1000 #kPa
# Out:
# \[
# \begin{aligned}
# p_{gauge} &= \rho_{water} \cdot g \cdot h \\&= 1000 \cdot 9.8 \cdot 10 \\&= 98100.0 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{gauge_{kPa}} &= \frac{ p_{gauge} }{ 1000 } \\&= \frac{ 98100.0 }{ 1000 } \\&= 98.1 \; \;\textrm{(kPa)}\\[10pt]
# \\[10pt]
# p_{abs} &= \frac{ p_{atm} + p_{gauge} }{ 1000 } \\&= \frac{ 101325 + 98100.0 }{ 1000 } \\&= 199.4 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 6 (*)[R]

# %% [markdown]
# The pressure vessel below contains glycerine to a depth of 2 m under pressure as shown. Find the pressure at the bottom of the tank. {74.68 kPa}

# %%
from PIL import Image
img = Image.open(r"figures/32.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=214x212 at 0x1F5C58618B0>

# %% [markdown]
# **Given:**

# %%
# %%render param
# h = 2 #m
# p_top=50 #kPa
# Out:
# \[
# \begin{aligned}
# h &= 2 \; \;\textrm{(m)}
#  &p_{top} &= 50 \; \;\textrm{(kPa)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
#
# The first step is read the density of glycerine in Table A.4
#
# To calculate the pressure of the glycerine the following equation should be used:  $p_{glycerine}=\rho_{glycerine} g h$ in this equation the units are the following $p=[Pa], \rho=[kg/m^3], g= [m/s^2], h=[m]$.
#
# To calculate the pressure at the bottom of the tank, the pressure at the top and the pressure due to the glycerine should be added $p_{bottom}= p_{top}+p_{glycerine}$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_glycerine=1258 #kg/m3
# p_top_Pa= p_top*1000 #Pa
# p_bottom= p_top_Pa+rho_glycerine*g*h #Pa
# p_bottom_kPa= p_bottom/1000 #kPa
# Out:
# \[
# \begin{aligned}
# \rho_{glycerine} &= 1258 \; \;\textrm{(kg/m3)}
# \\[10pt]
# p_{top_{Pa}} &= p_{top} \cdot 1000 \\&= 50 \cdot 1000 \\&= 50000 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{bottom} &= p_{top_{Pa}} + \rho_{glycerine} \cdot g \cdot h \\&= 50000 + 1258 \cdot 9.81 \cdot 2 \\&= 74681.96 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{bottom_{kPa}} &= \frac{ p_{bottom} }{ 1000 } \\&= \frac{ 74681.96 }{ 1000 } \\&= 74.68 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 7 (**)[R]

# %% [markdown]
# An open tank contains 10 m of water, covered with 1 m of oil with s = 0.80. Find the absolute pressure at (a) the interface between the two fluids and (b) the bottom of the tank. {109.1 kPa; 207.2 kPa}

# %% [markdown]
# **Given:**

# %%
# %%render param
# h_water= 10 #m
# h_oil= 1 #m
# s_oil= 0.8
# Out:
# \[
# \begin{aligned}
# h_{water} &= 10 \; \;\textrm{(m)}
#  &h_{oil} &= 1 \; \;\textrm{(m)}
#  &s_{oil} &= 0.800 \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The absolute pressure can be calculated as $ p_{abs}= p_{atm}+ p_{gauge}$
#
# where the absolute pressure can be assumed as 101325 Pa since it is an open tank and the gauge pressure at the interface between the two fluids can be calculated as $p_{gauge}=\rho_{oil} g h_{oil}$
#
# Remeber that $\rho_{oil}=s_{oil} \rho_{water}$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_oil= s_oil*rho_water #kg/m3
# p_abs1= p_atm+rho_oil*g*h_oil #Pa
# p_abs1_= p_abs1/1000 #kPa
# Out:
# \[
# \begin{aligned}
# \rho_{oil} &= s_{oil} \cdot \rho_{water} \\&= 0.80 \cdot 1000 \\&= 800.00 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# p_{abs1} &= p_{atm} + \rho_{oil} \cdot g \cdot h_{oil} \\&= 101325 + 800.00 \cdot 9.81 \cdot 1 \\&= 109173.00 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{abs1_{}} &= \frac{ p_{abs1} }{ 1000 } \\&= \frac{ 109173.00 }{ 1000 } \\&= 109.17 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The absolute pressure at the bottom of the tank can be calculated as the sum of the absoulte pressure at the interface of the fluids and the gauge pressure at the bottom of the tank. That is: $ p_{abs2}= p_{abs1}+ p_{gauge}$
#
# The gauge pressure at the bottom of the tank can be calculated as $p_{gauge}=\rho_{water}*g * h_{water}$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_abs2= p_abs1+rho_water*g*h_water #Pa
# p_abs2_= p_abs2/1000 #kPa
# Out:
# \[
# \begin{aligned}
# p_{abs2} &= p_{abs1} + \rho_{water} \cdot g \cdot h_{water} \\&= 109173.00 + 1000 \cdot 9.81 \cdot 10 \\&= 207273.00 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{abs2_{}} &= \frac{ p_{abs2} }{ 1000 } \\&= \frac{ 207273.00 }{ 1000 } \\&= 207.27 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 8 (**)

# %% [markdown]
# A pressure gauge at an elevation 4.8 m on the side of a storage tank containing oil reads 34.7 kPa. Another gauge at elevation 2.2 m reads 57.5 kPa. Calculate the specific weight, density and specific gravity of the oil. {8.77 kN/m<sup>3</sup>; 894 kg/m<sup>3</sup>; 0.894}

# %% [markdown]
# **Given:**

# %%
# %%render param 1
# h_1=4.8 #m
# p_gauge_1= 34.7 #kPa
# h_2=2.2 #m
# p_gauge_2= 57.5 #kPa
# Out:
# \[
# \begin{aligned}
# h_{1} &= 4.8 \; \;\textrm{(m)}
#  &p_{gauge_{1}} &= 34.7 \; \;\textrm{(kPa)}
#  &h_{2} &= 2.2 \; \;\textrm{(m)}
# \\[10pt]
#  p_{gauge_{2}} &= 57.5 \; \;\textrm{(kPa)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The first step is calculate the pressure and height difference between the two points and then use the equations for the requested parameters
#
# $$
# \Delta p= p_{gauge2}-p_{gauge1}
# $$
#
# $$
# \Delta h= h_1-h_2
# $$
#
# The next step is calculate the specific weight, density and specific gravity of the oil with the following equations:
#
# $$
# \gamma=\frac {\Delta p}{\Delta h}
# $$
#
# $$
# \rho=\frac {\gamma}{g}
# $$
#
# $$
# s= \frac {\gamma}{\gamma_{water}}
# $$
#
# The units of the variables are: $\gamma= [N/m^3], p= [Pa], h= [m], g = [m/s^2], \rho =[kg/m^3]$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# Delta_p= p_gauge_2-p_gauge_1 #kPa
# Delta_h= h_1-h_2 #m
# gamma= Delta_p/Delta_h #kN/m3
# gamma_oil=gamma*1000 #N/m3
# rho_oil= gamma_oil/g #kg/m3
# s_oil= rho_oil/(rho_water)
# Out:
# \[
# \begin{aligned}
# \Delta_{p} &= p_{gauge_{2}} - p_{gauge_{1}} \\&= 57.50 - 34.70 \\&= 22.80 \; \;\textrm{(kPa)}\\[10pt]
# \\[10pt]
# \Delta_{h} &= h_{1} - h_{2} \\&= 4.80 - 2.20 \\&= 2.60 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# \gamma &= \frac{ \Delta_{p} }{ \Delta_{h} } \\&= \frac{ 22.80 }{ 2.60 } \\&= 8.77 \; \;\textrm{(kN/m3)}\\[10pt]
# \\[10pt]
# \gamma_{oil} &= 8769.23 \; \;\textrm{(N/m3)}
# \\[10pt]
# \rho_{oil} &= \frac{ \gamma_{oil} }{ g } \\&= \frac{ 8769.23 }{ 9.81 } \\&= 893.91 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# s_{oil} &= \frac{ \rho_{oil} }{ \rho_{water} } \\&= \frac{ 893.91 }{ 1000 } \\&= 0.89  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 9 (**)

# %% [markdown]
# A closed vessel containing oil with a density of 830 kg/m<sup>3</sup> under pressure is shown below. The space above the oil is pressurised to 35 kPa above atmospheric pressure. Find the elevation of the oil surface in the attached tube. {6.3 m}

# %%
from PIL import Image
img = Image.open(r"figures/35.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=442x329 at 0x1D0C2420AF0>

# %% [markdown]
# **Given:**

# %%
# %%render param
# rho_oil=830 #kg/m3
# h_1=2 #m
# p_1=35000 #Pa
# Out:
# \[
# \begin{aligned}
# \rho_{oil} &= 830 \; \;\textrm{(kg/m3)}
#  &h_{1} &= 2 \; \;\textrm{(m)}
#  &p_{1} &= 35000 \; \;\textrm{(Pa)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The elevation of the oil is
#
# $$
# h_{oil}=h_1+h_2
# $$
#
# Where $h_1$ is given
#
# Considering that the pressure is the same at the same heigth in the same fluid, $h_2$ can be calculated as
#
# $$
# h_2=\frac{p1}{\rho_{oil} \cdot g}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# h_2= p_1/(rho_oil*g) #m
# h_oil= h_1+h_2 #m
# Out:
# \[
# \begin{aligned}
# h_{2} &= \frac{ p_{1} }{ \rho_{oil} \cdot g } \\&= \frac{ 83562.6 }{ 893.9 \cdot 9.8 } \\&= 9.5 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# h_{oil} &= h_{1} + h_{2} \\&= 4.8 + 9.5 \\&= 14.3 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 10 (**)[R]

# %% [markdown]
# Calculate the level h of the oil in the right-hand tube in the figure below. { 182 mm}

# %%
img = Image.open(r"figures/36.png")
img= img.resize((250,300))
img
# Out:
# <PIL.Image.Image image mode=RGBA size=250x300 at 0x1D0C22DD1C0>

# %% [markdown]
# **Given:**

# %%
# %%render param
# s=0.83
# h_oil =240 #mm
# h_tube=110 #mm
# h_water=280 #mm
# Out:
# \[
# \begin{aligned}
# s &= 0.830 \;
#  &h_{oil} &= 240 \; \;\textrm{(mm)}
#  &h_{tube} &= 110 \; \;\textrm{(mm)}
# \\[10pt]
#  h_{water} &= 280 \; \;\textrm{(mm)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %%
from PIL import Image
img = Image.open(r"figures/36S.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=436x441 at 0x1F5C5B9E700>

# %% [markdown]
# ```{toggle}
# The pressure in $p_1$ and $p_2$ are the same because is the same fluid in the same height. Considering the pressure can be calculated as $p=\rho gh$
#
# The pressure in points 2 and 1 can be calculated as:
#
# $$
# p_2 = \rho_{oil} \cdot g \cdot (h+h_{oil}) \\
# $$
#
# $$
# p_1= \rho_{water} \cdot  g \cdot (h_{oil}+h_{tube})\\
# $$
#
# The pressure in point 1 can be calculated because all the variables are given. Once this value has been calculated, the nex step is equalizing both pressures
#
# $$
# \rho_{oil} \cdot g \cdot (h+h_{oil})= p_1\\
# $$
#
# $$
# h= \frac {p_1}{\rho _{oil} \cdot g} -h_{oil}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# rho_oil = s*rho_water
# p_1= (h_tube+h_oil)*10**-3*g*rho_water #Pa
# h= p_1/(rho_oil*g)-(h_oil*10**-3) #m
# h_mm= h*1000 #mm
# Out:
# \[
# \begin{aligned}
# \rho_{oil} &= s \cdot \rho_{water} \\&= 0.8 \cdot 1000 \\&= 830.0  \\[10pt]
# \\[10pt]
# p_{1} &= \left( h_{tube} + h_{oil} \right) \cdot \left( 10 \right) ^{ -3 } \cdot g \cdot \rho_{water} \\&= \left( 110 + 240 \right) \cdot \left( 10 \right) ^{ -3 } \cdot 9.8 \cdot 1000 \\&= 3433.5 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# h &= \frac{ p_{1} }{ \rho_{oil} \cdot g } - \left( h_{oil} \cdot \left( 10 \right) ^{ -3 } \right) \\&= \frac{ 3433.5 }{ 830.0 \cdot 9.8 } - \left( 240 \cdot \left( 10 \right) ^{ -3 } \right) \\&= 0.2 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# h_{mm} &= h \cdot 1000 \\&= 0.2 \cdot 1000 \\&= 181.7 \; \;\textrm{(mm)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 11 (**)

# %% [markdown]
# An open tube is attached to a tank as shown below. If the water rises to a height of 800 mm in the tube, what are the pressures pA and pB of the air above the water? Neglect capillary effects. {3.92 kPa, 4.91 kPa}

# %%
from PIL import Image
img = Image.open(r"figures/37.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=469x249 at 0x1D0C26AE910>

# %% [markdown]
# **Given:**

# %%
# %%render param 1
# h_1= 100*10**-3 #m
# h_2= 300*10**-3 #m
# h_3=800*10**-3 #m
# Out:
# \[
# \begin{aligned}
# h_{1} &= 0.1 \; \;\textrm{(m)}
#  &h_{2} &= 0.3 \; \;\textrm{(m)}
#  &h_{3} &= 0.8 \; \;\textrm{(m)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The pressure can be calculated as $p=\rho_{water}gh$
#
# At point A, $h$ is equal to $h_3-h_2-h_1$, with that the pressure for point A is:
#
# $$
# p_A=\rho_{water} \cdot g \cdot (h_3-h_2-h_1)
# $$
#
# and at point B, $h$ is equal to $h_3-h_2$  , with that the pressure for point B is:
#
# $$
# p_B=\rho_{water} \cdot g \cdot (h_3-h_2)
# $$
#
# Note that to convert the pressures from Pa to kPa, the pressures need to be divided by 1000.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_A= (rho_water*g*(h_3-h_2-h_1))/1000 #kPa
# p_B= (rho_water*g*(h_3-h_2))/1000 #kPa
# Out:
# \[
# \begin{aligned}
# p_{A} &= \frac{ \rho_{water} \cdot g \cdot \left( h_{3} - h_{2} - h_{1} \right) }{ 1000 } \\&= \frac{ 1000 \cdot 9.81 \cdot \left( 0.80 - 0.30 - 0.10 \right) }{ 1000 } \\&= 3.92 \; \;\textrm{(kPa)}\\[10pt]
# \\[10pt]
# p_{B} &= \frac{ \rho_{water} \cdot g \cdot \left( h_{3} - h_{2} \right) }{ 1000 } \\&= \frac{ 1000 \cdot 9.81 \cdot \left( 0.80 - 0.30 \right) }{ 1000 } \\&= 4.91 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 12 (***)

# %% [markdown]
# A submarine is situated 1000 m below sea level. The pressure inside the submarine is controlled. If water inside the submarine boils at a temperature of 90°C, what is the pressure difference between the inside and outside of the submarine? Take the density of sea water as 1 023 kg/m<sup>3</sup>. {10.1 MPa}

# %% [markdown]
# **Given:**

# %%
# %%render param
# h=1000 #m
# rho_sea_water=1023 #kg/m3
# Out:
# \[
# \begin{aligned}
# h &= 1000 \; \;\textrm{(m)}
#  &\rho_{sea_{water}} &= 1023 \; \;\textrm{(kg/m3)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# For the pressure difference the following equation has to be used:
#
# $$
# \Delta p= p_{out} - p_{in}
# $$
#
# The pressure outside the submarine can be calculated as the sum of the atmospheric pressure at sea level and the pressure due to the water column above the submarine
#
# $$
# p_{out}=p_{atm} + \rho_{seawater} \cdot g \cdot h
# $$
#
#
# The pressure inside the submarine can be determined using the boiling point of water from standard reference tables (Table A.1)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# p_out= (p_atm + rho_sea_water*g*h)/1000  #kPa
# p_v=70.1 #kPa
# Delta_p= (p_out-p_v)/1000 #MPa
# Out:
# \[
# \begin{aligned}
# p_{out} &= \frac{ p_{atm} + \rho_{sea_{water}} \cdot g \cdot h }{ 1000 } \\&= \frac{ 101325 + 1023 \cdot 9.8 \cdot 1000 }{ 1000 } \\&= 10137.0 \; \;\textrm{(kPa)}\\[10pt]
# \\[10pt]
# p_{v} &= 70.1 \; \;\textrm{(kPa)}
# \\[10pt]
# \Delta_{p} &= \frac{ p_{out} - p_{v} }{ 1000 } \\&= \frac{ 10137.0 - 70.1 }{ 1000 } \\&= 10.1 \; \;\textrm{(MPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ## Problems for Lecture 5: Manometry

# %% [markdown]
# ### Piezometers

# %% [markdown]
# ---
# #### Question 1 (*)

# %% [markdown]
# A piezometer is attached to the top of a pressure vessel with a pressure of 25 kPa. If the vessel is filled with a fluid that has a specific gravity of 1.85, how high would the fluid rise in the piezometer? {1.38 m}

# %% [markdown]
# **Given:**

# %%
# %%render param 2
# p=25000 #Pa
# s_fluid=1.85
# Out:
# \[
# \begin{aligned}
# p &= 25000 \; \;\textrm{(Pa)}
#  &s_{fluid} &= 1.85 \;
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The height in the piezometer can be calculated as
#
# $$
# h=\frac{p}{\rho_{fluid} \cdot g}
# $$
#
# where $\rho_{fluid}=s_{fluid} \cdot \rho_{water}$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_fluid= s_fluid*rho_water #kg/m3
# h= p/(rho_fluid*g) #m
# Out:
# \[
# \begin{aligned}
# \rho_{fluid} &= s_{fluid} \cdot \rho_{water} \\&= 1.85 \cdot 1000 \\&= 1850.00 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# h &= \frac{ p }{ \rho_{fluid} \cdot g } \\&= \frac{ 25000 }{ 1850.00 \cdot 9.81 } \\&= 1.38 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2 (**)

# %% [markdown]
# An open tank has two piezometers attached to its side as shown below. The tank contains two immiscible (non-mixing) liquids. Find the a) elevation of the liquid surface in piezometer A, b) elevation of the liquid surface in piezometer B and c) the pressure at the bottom of the tank.  {2 m; 0.82 m; 18.9 kPa}

# %%
from PIL import Image
img = Image.open(r"figures/40.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=478x379 at 0x1D0C218FCA0>

# %% [markdown]
# **Given:**

# %%
# %%render param
# h_t=2 #m
# h_B=0.3 #m
# s_A=0.72
# s_B=2.36
# h_A= h_t-h_B #m
# Out:
# \[
# \begin{aligned}
# h_{t} &= 2 \; \;\textrm{(m)}
#  &h_{B} &= 0.300 \; \;\textrm{(m)}
#  &s_{A} &= 0.720 \;
# \\[10pt]
#  s_{B} &= 2.360 \;
#  &h_{A} &= 1.700 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{toggle}
# The liquid A will simply rise in piezometer A to the same elevation as liquid A in the tank (2 m)
# ```

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# To calculate the height of liquid B the following equation should be used:
#
# $$
# p_B=\rho_B \cdot g \cdot h
# $$
#
# Solving for h the equation is
#
# $$
# h= \frac {p_B}{\rho_B  \cdot g}
# $$
#
# To calulate the $\rho_B$ the equation is the following: $\rho_B= s \cdot \rho_{water}$
#
# The gauge pressure in Liquid B is the pressure exerted by Liquid A with a height of 1.7 m.  The pressure of the Liquid A can be calculated using $p_A=\rho_A \cdot g \cdot h_A$. Considering that $h_A$ is the height of the Liquid A, which is the difference between the total height of the tank and the height of the liquid B.
#
# The pressure of $p_A$ is igual to $p_B$ at the interface of the two liquids.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_A=s_A*rho_water # kg/m3
# p_B= rho_A*g*(h_A) #Pa
# rho_B= s_B*g*rho_water #kg/m3
# h= p_B/(rho_B) #m
# h_liquid_b= h_B+h #m
# Out:
# \[
# \begin{aligned}
# \rho_{A} &= 720.00 \; \;\textrm{(kg/m3)}
# \\[10pt]
# p_{B} &= \rho_{A} \cdot g \cdot h_{A} \\&= 720.00 \cdot 9.81 \cdot 1.70 \\&= 12007.44 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# \rho_{B} &= s_{B} \cdot g \cdot \rho_{water} \\&= 2.36 \cdot 9.81 \cdot 1000 \\&= 23151.60 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# h &= \frac{ p_{B} }{ \rho_{B} } \\&= \frac{ 12007.44 }{ 23151.60 } \\&= 0.52 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# h_{liquid_{b}} &= h_{B} + h \\&= 0.30 + 0.52 \\&= 0.82 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# c)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The pressure at the bottom is the sum of the pressure exerted by Liquid A and Liquid B
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_bottom = (s_A*g*(h_A))+s_B*g*h_B #kPa
# Out:
# \[
# \begin{aligned}
# p_{bottom} &= \left( s_{A} \cdot g \cdot h_{A} \right) + s_{B} \cdot g \cdot h_{B} \\&= \left( 0.720 \cdot 9.810 \cdot 1.700 \right) + 2.360 \cdot 9.810 \cdot 0.300 \\&= 18.953 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Barometers

# %% [markdown]
# ---
# #### Question 3(*)

# %% [markdown]
# What is the atmospheric pressure if a mercury barometer reads 742 mm? Work from basic principles. Assume &rho;<sub>Hg</sub> = 13 600 kg/m<sup>3</sup>. {99.0 kPa}

# %% [markdown]
# **Given:**

# %%
# %%render param
# h=0.742 #m
# rho_Hg_=13600 #kg/m3
# Out:
# \[
# \begin{aligned}
# h &= 0.742 \; \;\textrm{(m)}
#  &\rho_{Hg_{}} &= 13600 \; \;\textrm{(kg/m3)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# Pressure can be estimated as $p=\rho \cdot g \cdot h$.
#
# In this case, $\rho$ corresponds to the density of mercury and $h$ is the height read in the barometer.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# p= rho_Hg_*g*h #Pa
# p_kPa= p/1000 #kPa
# Out:
# \[
# \begin{aligned}
# p &= \rho_{Hg_{}} \cdot g \cdot h \\&= 13600 \cdot 9.8 \cdot 0.7 \\&= 98994.7 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{kPa} &= \frac{ p }{ 1000 } \\&= \frac{ 98994.7 }{ 1000 } \\&= 99.0 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 4 (**)

# %% [markdown]
# A scientist plans to build a water barometer. When the atmospheric pressure is 990 mb abs and the water temperature 70°C, what would you expect the barometer reading to be? {7.07 m}

# %%
from PIL import Image
img = Image.open(r"figures/42.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=308x341 at 0x1D0C23AA070>

# %% [markdown]
# **Given:**

# %%
# %%render param
# p_atm_ex= 990 #mb
# Out:
# \[
# \begin{aligned}
# p_{atm_{ex}} &= 990 \; \;\textrm{(mb)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# According to the image of the barometer, atmospheric pressure is the sum of the vapor pressure of the liquid and the pressure of the liquid
#
# $$
# p_{atm}= p_v+\rho_{liquid} \cdot g \cdot h
# $$
#
# or
#
# $$
# p_{atm}= p_v+\gamma_{liquid} \cdot h
# $$
#
# Read in Table A.1 the specific weight and the saturation vapor presure head in 70°C
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# gamma= 9.589 #kN/m3
# p_v= 31.16 #kN/m2
# p_atm_kPa= p_atm_ex*0.1 #kPa
# h_barom= p_atm_kPa/gamma-p_v/gamma #m
# Out:
# \[
# \begin{aligned}
# \gamma &= 9.589 \; \;\textrm{(kN/m3)}
# \\[10pt]
# p_{v} &= 31.160 \; \;\textrm{(kN/m2)}
# \\[10pt]
# p_{atm_{kPa}} &= p_{atm_{ex}} \cdot 0.1 \\&= 990 \cdot 0.1 \\&= 99.000 \; \;\textrm{(kPa)}\\[10pt]
# \\[10pt]
# h_{barom} &= \frac{ p_{atm_{kPa}} }{ \gamma } - \frac{ p_{v} }{ \gamma } \\&= \frac{ 99.000 }{ 9.589 } - \frac{ 31.160 }{ 9.589 } \\&= 7.075 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 5 (***)

# %% [markdown]
# A mercury barometer has a reading of 750 mm. Sketch this scenario and work from basic principles to calculate the atmospheric pressure. What is the impact on the reading of ignoring Mercury’s vapour pressure? Assume &rho;<sub>Hg</sub> = 13 550 kg/m<sup>3</sup>. {99.69 kPa; 0.0002 %, i.e. negligible}

# %% [markdown]
# **Given:**

# %%
# %%render param 2
# h=0.75 #m
# rho_Hg_=13550 #kg/m3
# Out:
# \[
# \begin{aligned}
# h &= 0.75 \; \;\textrm{(m)}
#  &\rho_{Hg_{}} &= 13550 \; \;\textrm{(kg/m3)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The atmosferic pressure is equal to the sum of the vapour pressure of mercury and the gauge pressure read in the barometer:
#
# $$ p_{atm}=p_{vHg}+(\rho_{Hg} \cdot g \cdot h) $$
#
#
# The impact of ignoring the vapor pressure of mercury can be calculated as the fraction that the vapour pressure represents in the atmosferic pressure:
#
# $$ Effect_{Hg}=\frac{p_{vHg}}{p_{atm}} $$
#
# Note that, from Table A.4, the vapor pressure of mercury is 0.17 N/m<sup>2</sup>
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# p_vHg=0.17 #N/m2
# p_atm_= p_vHg+(rho_Hg_*g*h) #Pa
# p_atm__= p_atm_/1000 #kPa
# Effect_Hg= (0.17/p_atm_)*100 #%
# Out:
# \[
# \begin{aligned}
# p_{vHg} &= 0.1700 \; \;\textrm{(N/m2)}
# \\[10pt]
# p_{atm_{}} &= p_{vHg} + \left( \rho_{Hg_{}} \cdot g \cdot h \right) \\&= 0.1700 + \left( 13550 \cdot 9.8100 \cdot 0.7500 \right) \\&= 99694.2950 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{atm_{_{}}} &= \frac{ p_{atm_{}} }{ 1000 } \\&= \frac{ 99694.2950 }{ 1000 } \\&= 99.6943 \; \;\textrm{(kPa)}\\[10pt]
# \\[10pt]
# \mathrm{Effect}_{Hg} &= \left( \frac{ 0.17 }{ p_{atm_{}} } \right) \cdot 100 \\&= \left( \frac{ 0.17 }{ 99694.2950 } \right) \cdot 100 \\&= 0.0002 \; \;\textrm{(%)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Manometers

# %% [markdown]
# ---
# #### Question 6 (**)[R]

# %% [markdown]
# A manometer is attached to a water tank as shown below. Find the height of the free water surface above the bottom of the tank. Work from basic principles. Assume ρ<sub>Hg</sub> = 13 600 kg/m<sup>3</sup>. {2.87 m}

# %%
from PIL import Image
img = Image.open(r"figures/44.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=709x382 at 0x1D0C24BE790>

# %% [markdown]
# **Given:**

# %%
# %%render param
# rho_Hg_= 13600 #kg/m3
# x_1=0.15 #m
# x_2= 0.15 #m
# x_3= 0.20 #m
# Out:
# \[
# \begin{aligned}
# \rho_{Hg_{}} &= 13600 \; \;\textrm{(kg/m3)}
#  &x_{1} &= 0.150 \; \;\textrm{(m)}
#  &x_{2} &= 0.150 \; \;\textrm{(m)}
# \\[10pt]
#  x_{3} &= 0.200 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %%
from PIL import Image
img = Image.open(r"figures/44s.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1067x647 at 0x1D0C23C31C0>

# %% [markdown]
# ```{toggle}
# $p_1 =p_2 $ because they are on the same level and same fluid
#
#
# $$
# p_1 = \rho_{Hg} \cdot  g \cdot x_3\\
# $$
#
# $$
# p_2 = \rho_{water} \cdot g \cdot x_1 + \rho_{water} \cdot g \cdot (H-x_1 -x_2)\\
# $$
#
# Simplyfing $p_2$
#
# $$
# p_2 = \rho_{water} \cdot g \cdot (H-x_2)
# $$
#
# Equalizing the two pressures
#
# $$
# \rho_{water} \cdot g \cdot (H-x_2)=\rho_{Hg} \cdot g \cdot x_3 \\
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# H= (rho_Hg_*g*x_3)/(rho_water*g)+x_2 #m
# Out:
# \[
# \begin{aligned}
# H &= \frac{ \rho_{Hg_{}} \cdot g \cdot x_{3} }{ \rho_{water} \cdot g } + x_{2} \\&= \frac{ 13600 \cdot 9.81 \cdot 0.20 }{ 1000 \cdot 9.81 } + 0.15 \\&= 2.87 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 7 (**)[R]

# %% [markdown]
# Calculate the difference in manometer mercury levels (y) in the figure below from basic principles. Assume ρ<sub>Hg</sub> = 13 600 kg/m<sup>3</sup>. {626 mm}

# %%
from PIL import Image
img = Image.open(r"figures/45.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=723x545 at 0x1D0C23C34F0>

# %% [markdown]
# **Given:**

# %%
# %%render param
# rho_Hg_=13600 #kg/m3
# s_oil=0.82
# h_1=1 #m
# h_2=2 #m
# h_3=5 #m
# h_4=6 #m
# p_3=30000 #Pa
# Out:
# \[
# \begin{aligned}
# \rho_{Hg_{}} &= 13600 \; \;\textrm{(kg/m3)}
#  &s_{oil} &= 0.820 \;
#  &h_{1} &= 1 \; \;\textrm{(m)}
# \\[10pt]
#  h_{2} &= 2 \; \;\textrm{(m)}
#  &h_{3} &= 5 \; \;\textrm{(m)}
#  &h_{4} &= 6 \; \;\textrm{(m)}
# \\[10pt]
#  p_{3} &= 30000 \; \;\textrm{(Pa)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
#
# The pressure corresponding to height 'y' is equal to the pressure at (1) because it is the same level and the same fluid. Therefore, this height can be calcuated as:
#
# $$y=\frac{p_1}{\rho_{Hg} \cdot g}$$
#
# For that reason, it is necessary to calculate the $p_1$. For this the following process can be developed.
#
# The first step is to calculate the pressure in point 2 $p_2$ which is equal to the sum of the pressure at (3) and the pressure of the oil from (3) to (2):
#
# $$p_2=p_3+\rho_{oil} \cdot g \cdot (h_3-h_2)$$
#
# Once the pressure in the point 2 is calculated, it is possible to determine the pressure in point 1 because $p_1$ is equal to the sum of the pressure at (2) and the pressure of the water from (2) to (1):
#
# $$p_1=p_2+\rho_{water} \cdot g \cdot (h_2+h_1)$$
#
# Remember that $\rho_{oil}=s_{oil} \cdot \rho_{oil}$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_oil= s_oil*rho_water #kg/m3
# p_2= p_3+rho_oil*g*(h_3-h_2) #Pa
# p_1= p_2+rho_water*g*(h_2+(h_1)) #Pa
# y= p_1/(rho_Hg_*g) #m
# y_mm= y*1000 #mm
# Out:
# \[
# \begin{aligned}
# \rho_{oil} &= s_{oil} \cdot \rho_{water} \\&= 0.82 \cdot 1000 \\&= 820.00 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# p_{2} &= p_{3} + \rho_{oil} \cdot g \cdot \left( h_{3} - h_{2} \right) \\&= 30000 + 820.00 \cdot 9.81 \cdot \left( 5 - 2 \right) \\&= 54132.60 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{1} &= p_{2} + \rho_{water} \cdot g \cdot \left( h_{2} + h_{1} \right) \\&= 54132.60 + 1000 \cdot 9.81 \cdot \left( 2 + 1 \right) \\&= 83562.60 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# y &= \frac{ p_{1} }{ \rho_{Hg_{}} \cdot g } \\&= \frac{ 83562.60 }{ 13600 \cdot 9.81 } \\&= 0.63 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# y_{mm} &= y \cdot 1000 \\&= 0.63 \cdot 1000 \\&= 626.33 \; \;\textrm{(mm)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 8 (**)

# %% [markdown]
# Calculate the pressure pa in the figure below if the specific gravity of the oil is 0.82. Assume ρ<sub>Hg</sub> = 13 600 kg/m<sup>3</sup> {8.7 kPa}

# %% [markdown]
# **Given:**

# %%
from PIL import Image
img = Image.open(r"figures/46.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=510x328 at 0x1D0C24BE640>

# %%
# %%render param
# rho_Hg_= 13600 #kg/m3
# s_oil= 0.82
# y_oil= 3 #m
# y_man= 320 #mm
# y_oil_water= 4 #m
# Out:
# \[
# \begin{aligned}
# \rho_{Hg_{}} &= 13600 \; \;\textrm{(kg/m3)}
#  &s_{oil} &= 0.820 \;
#  &y_{oil} &= 3 \; \;\textrm{(m)}
# \\[10pt]
#  y_{man} &= 320 \; \;\textrm{(mm)}
#  &y_{oil_{water}} &= 4 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %%
img2 = Image.open(r"figures/46s.png")
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=621x409 at 0x1D0C244F4C0>

# %% [markdown]
# ```{toggle}
# Pressure in 1 and 2 is the same because is a const static fluid.
#
# $$p_1= p_2 $$
#
# $$
# p_1= \rho_{Hg} g y_{man} \\
# $$
#
# $$
# p3=p_A + \rho_{oil} \cdot g \cdot y_{oil}\\
# $$
#
# $$
# p_2= p_3+ \rho_{water} \cdot g \cdot (y_{oil_{water}}-y_{oil})
# $$
#
# Using the three equations we can arrive at the following
#
# $$
# p_A + \rho_{oil} \cdot g  \cdot y_{oil}=-\rho_{water} \cdot g \cdot (y_{oil_{water}}-y_{oil})+\rho_{Hg} \cdot g \cdot y_{man}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_oil=s_oil*rho_water # kg/m3
# p_A= -(rho_oil*g*y_oil)-g*rho_water*(y_oil_water-y_oil)+rho_Hg_*g*y_man/1000 #Pa
# Out:
# \[
# \begin{aligned}
# \rho_{oil} &= 820.00 \; \;\textrm{(kg/m3)}
# \\[10pt]
# P_{A} &= \left( - \left( \rho_{oil} \cdot g \cdot y_{oil} \right) \right) - g \cdot \rho_{water} \cdot \left( y_{oil_{water}} - y_{oil} \right) + \rho_{Hg_{}} \cdot g \cdot \frac{ y_{man} }{ 1000 } \\&= \left( - \left( 820.00 \cdot 9.81 \cdot 3 \right) \right) - 9.81 \cdot 1000 \cdot \left( 4 - 3 \right) + 13600 \cdot 9.81 \cdot \frac{ 320 }{ 1000 } \\&= 8750.52 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 9 (*)(**)

# %% [markdown]
# A mercury manometer is used to measure the pressure in a vessel containing water as shown in the figure below. The following measurements were taken:
# $h_1$ = 300mm and $h_2$ = 150mm.
#
# a.* What was the pressure in the vessel at its center (point A) based on the measured values? {38.4 kPa}
# b.** If the diameter of the pressure vessel is 2m, what is the pressure at its bottom? {48.2 kPa}
# c.*** It is later discovered that an air bubble with an effective height of 10 mm was trapped in the water of the left leg of the manometer when the readings were taken. Calculate the corrected pressure in the container if this bubble is taken into consideration. {38.5 kPa}

# %%
from PIL import Image
img = Image.open(r"figures/47.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=207x250 at 0x1D0C244FCD0>

# %% [markdown]
# **Given:**

# %%
# %%render param 2
# h_1=0.3 #m
# h_2=0.15 #m
# d=2 #m
# h_bubble=0.01 #m
# Out:
# \[
# \begin{aligned}
# h_{1} &= 0.30 \; \;\textrm{(m)}
#  &h_{2} &= 0.15 \; \;\textrm{(m)}
#  &d &= 2 \; \;\textrm{(m)}
# \\[10pt]
#  h_{bubble} &= 0.01 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# Considering that the pressure is the same at the same level in the same fluid, we have the following equation:
#
# $$
# p_A+\rho_{water} \cdot g \cdot h_2=\rho_{Hg} \cdot g \cdot h_1
# $$
#
# Therefore, solving for $p_A$:
#
# $$
# p_A=\rho_{Hg} \cdot g \cdot h_1-\rho_{water} \cdot g \cdot h_2
# $$
#
#
# Note: the Mercury's density can be assumed as $\rho_{Hg}=13550 kg/m^3$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_Hg_= 13550 #kg/m3
# p_A= rho_Hg_*g*h_1-rho_water*g*h_2 #Pa
# p_A_= p_A/1000 #kPa
# Out:
# \[
# \begin{aligned}
# \rho_{Hg_{}} &= 13550 \; \;\textrm{(kg/m3)}
# \\[10pt]
# p_{A} &= \rho_{Hg_{}} \cdot g \cdot h_{1} - \rho_{water} \cdot g \cdot h_{2} \\&= 13550 \cdot 9.81 \cdot 0.30 - 1000 \cdot 9.81 \cdot 0.15 \\&= 38406.15 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{A_{}} &= \frac{ p_{A} }{ 1000 } \\&= \frac{ 38406.15 }{ 1000 } \\&= 38.41 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The pressure at the bottom is equal to the pressure at A plus the pressure from point A to the bottom. This can be expressed as the following equation:
#
# $$p_{bottom}=p_{A}+\rho_{water} \cdot g \cdot \frac{d}{2}$$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_bottom= p_A+rho_water*g*(d/2) #Pa
# p_bottom_= p_bottom/1000 #kPa
# Out:
# \[
# \begin{aligned}
# p_{bottom} &= p_{A} + \rho_{water} \cdot g \cdot \left( \frac{ d }{ 2 } \right) \\&= 38406.15 + 1000 \cdot 9.81 \cdot \left( \frac{ 2 }{ 2 } \right) \\&= 48216.15 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{bottom_{}} &= \frac{ p_{bottom} }{ 1000 } \\&= \frac{ 48216.15 }{ 1000 } \\&= 48.22 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# c)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The bubble reduces the height of the water by 10mm, therefore the pressure in the container is:
#
# $$
# p_A=\rho_{Hg} \cdot g \cdot h_1-\rho_{water} \cdot g \cdot (h_2-h_{bubble})
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_A= rho_Hg_*g*h_1-rho_water*g*(h_2-h_bubble) #Pa
# p_A_= p_A/1000 #kPa
# Out:
# \[
# \begin{aligned}
# p_{A} &= \rho_{Hg_{}} \cdot g \cdot h_{1} - \rho_{water} \cdot g \cdot \left( h_{2} - h_{bubble} \right) \\&= 13550 \cdot 9.81 \cdot 0.30 - 1000 \cdot 9.81 \cdot \left( 0.15 - 0.01 \right) \\&= 38504.25 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{A_{}} &= \frac{ p_{A} }{ 1000 } \\&= \frac{ 38504.25 }{ 1000 } \\&= 38.50 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 10 (**)[R]

# %% [markdown]
# What is the pressure difference between points A and B in the system below? Work from basic principles. Assume ρ<sub>Hg</sub> = 13550 kg/m<sup>3</sup>. {10.1 kPa}

# %%
from PIL import Image
img = Image.open(r"figures/48.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=399x199 at 0x1D0C232A220>

# %% [markdown]
# **Given:**

# %%
# %%render param
# rho_Hg_= 13550 #kg/m3
# rho_benz=876 #kg/m3
# rho_kero= 808 #kg/m3
# rho_air=1.22 #kg/m3
# y_benz= 21 #cm
# y_Hg= 9 #cm
# y_water1= 41 #cm
# y_air= 10 #cm
# y_water2= 15 #cm
# Out:
# \[
# \begin{aligned}
# \rho_{Hg_{}} &= 13550 \; \;\textrm{(kg/m3)}
#  &\rho_{benz} &= 876 \; \;\textrm{(kg/m3)}
#  &\rho_{kero} &= 808 \; \;\textrm{(kg/m3)}
# \\[10pt]
#  \rho_{air} &= 1.220 \; \;\textrm{(kg/m3)}
#  &y_{benz} &= 21 \; \;\textrm{(cm)}
#  &y_{Hg} &= 9 \; \;\textrm{(cm)}
# \\[10pt]
#  y_{water1} &= 41 \; \;\textrm{(cm)}
#  &y_{air} &= 10 \; \;\textrm{(cm)}
#  &y_{water2} &= 15 \; \;\textrm{(cm)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %%
from PIL import Image
img = Image.open(r"figures/48s.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=534x234 at 0x21F15A1FB80>

# %% [markdown]
# ```{toggle}
# Considering that the same fluid at the same height has the same pressure, the following points have equal pressures
# $p_1=p_2, p_3=p_4, p_5=p_6$.
#
# Furthermore, taking into account that the pressure is greater when a point is lower, that is, the pressures should be added.For exmaple, the pressure in point 1 is higher than the pressure in A. For that reason, $p_1=p_A + \rho_{benz} \cdot g  \cdot y_{benz}$
#
# Considering the points of equal pressure and the statement explained previously, the following equations can be obtained.
#
# $$
# p_1=p_A + \rho_{benz} \cdot g \cdot y_{benz}\\
# $$
#
# $$
# p_3=p_1-\rho_{Hg} \cdot g \cdot y_{Hg}-\rho_{kero} \cdot g \cdot (y_{water_1}-y_{Hg})\\
# $$
#
# $$
# p_5= p_4 + \rho_{water} \cdot g \cdot y_{water_1}\\
# $$
#
# $$
# p_B=p_6-\rho_{water} \cdot g \cdot h_{kero}-\rho_{air} \cdot g \cdot y_{air}
# $$
#
# For the pressure diference between A and B all the equations should be used.
#
# $$
# \Delta _{p_{AB}}= -\rho_{benz} \cdot g \cdot y_{benz} + \rho_{Hg} \cdot g \cdot y_{Hg}+\rho_{kero} \cdot g \cdot (y_{water_1}-y_{Hg}) - \rho_{water} \cdot g \cdot y_{water_1}+ \rho_{water} \cdot g \cdot h_{kero}+\rho_{air} \cdot g \cdot  y_{air}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# Delta_p_AB= -rho_benz*g*y_benz/100 +rho_Hg_*g*y_Hg/100+rho_kero*g*(y_water1-y_Hg)/100 -rho_water*g*y_water1/100+rho_water*g*y_water2/100+rho_air*g*y_air/100 #Pa
# Out:
# \[
# \begin{aligned}
# \Delta_{p_{AB}} &= \left( - \rho_{benz} \right) \cdot g \cdot \frac{ y_{benz} }{ 100 } + \rho_{Hg_{}} \cdot g \cdot \frac{ y_{Hg} }{ 100 } + \rho_{kero} \cdot g \cdot \frac{ y_{water1} - y_{Hg} }{ 100 } - \rho_{water} \cdot g \cdot \frac{ y_{water1} }{ 100 } + \rho_{water} \cdot g \cdot \frac{ y_{water2} }{ 100 } + \rho_{air} \cdot g \cdot \frac{ y_{air} }{ 100 } \\&= \left( - 876 \right) \cdot 9.81 \cdot \frac{ 21 }{ 100 } + 13550 \cdot 9.81 \cdot \frac{ 9 }{ 100 } + 808 \cdot 9.81 \cdot \frac{ 41 - 9 }{ 100 } - 1000 \cdot 9.81 \cdot \frac{ 41 }{ 100 } + 1000 \cdot 9.81 \cdot \frac{ 15 }{ 100 } + 1.22 \cdot 9.81 \cdot \frac{ 10 }{ 100 } \\&= 10145.72 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Inverted Manometers

# %% [markdown]
# ---
# #### Question 11 (***)

# %% [markdown]
# In the figure below, the liquid at A and B is water and the manometer liquid is oil with s = 0.80, h<sub>1</sub> = 300 mm, h<sub>2</sub> = 200 mm, and h<sub>3</sub> = 600 mm. a) Determine the difference between the pressures at A and B. b) if pB = 50 kPa and the barometer reading is 730 mm Hg, find the absolute pressure head at A in meters of water. Assume ρ<sub>Hg</sub> = 13600 kg/m<sup>3</sup>. {-1.37 kPa, 14.9 m abs}

# %%
from PIL import Image
img = Image.open(r"figures/49.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=327x333 at 0x1D0C2435CA0>

# %% [markdown]
# **Given:**

# %%
# %%render param 1
# s_oil=0.8
# h_1=0.3 #m
# h_2=0.2 #m
# h_3=0.6 #m
# Out:
# \[
# \begin{aligned}
# s_{oil} &= 0.8 \;
#  &h_{1} &= 0.3 \; \;\textrm{(m)}
#  &h_{2} &= 0.2 \; \;\textrm{(m)}
# \\[10pt]
#  h_{3} &= 0.6 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
#  ```{toggle}
#  The difference between the pressures at A an B can be expressed as follows:
#
#  $$dp_{AB}=-p_3+p_1+p_2$$
#
#  Considering that:
#
#  $$p_1=\rho_{water} \cdot g \cdot h_1$$
#  $$p_2=\rho_{oil} \cdot g \cdot h_2$$
#  $$p_3=\rho_{water} \cdot g \cdot  h_3$$
#
#  We can reeplace the pressure equations to obtain:
#
#  $$dp_{AB}=-\rho_{water} \cdot g  \cdot h_3+\rho_{water} \cdot g \cdot h_1+\rho_{oil} \cdot g \cdot h_2$$
#
#  ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# rho_oil= s_oil*rho_water #kg/m3
# dp_AB= -rho_water*g*h_3+rho_oil*g*h_2+rho_water*g*h_1 #Pa
# dp_AB_= dp_AB/1000 #kPa
# Out:
# \[
# \begin{aligned}
# \rho_{oil} &= s_{oil} \cdot \rho_{water} \\&= 0.80 \cdot 1000 \\&= 800.00 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# \mathrm{dp}_{AB} &= \left( - \rho_{water} \right) \cdot g \cdot h_{3} + \rho_{oil} \cdot g \cdot h_{2} + \rho_{water} \cdot g \cdot h_{1} \\&= \left( - 1000 \right) \cdot 9.81 \cdot 0.60 + 800.00 \cdot 9.81 \cdot 0.20 + 1000 \cdot 9.81 \cdot 0.30 \\&= -1373.40 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# \mathrm{dp}_{AB_{}} &= \frac{ \mathrm{dp}_{AB} }{ 1000 } \\&= \frac{ -1373.40 }{ 1000 } \\&= -1.37 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Given:**

# %%
# %%render param 2
# p_B=50000 #Pa
# h_Hg= 0.730 #m Hg
# rho_Hg_=13600 #kg/m3
# Out:
# \[
# \begin{aligned}
# p_{B} &= 50000 \; \;\textrm{(Pa)}
#  &h_{Hg} &= 0.73 \; \;\textrm{(m Hg)}
#  &\rho_{Hg_{}} &= 13600 \; \;\textrm{(kg/m3)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# Pressure at A is equal to the pressure at B plus the pressure difference:
#
# $$p_A=p_B+dp_{AB}$$
# $$p_A=p_B+(-\rho_{water} \cdot g \cdot h_3+\rho_{water} \cdot g \cdot h_1+\rho_{oil} \cdot g \cdot h_2)$$
#
# Now, to convert Hg height to water height, first, we equal the pressure of water to the pressure of Mercury:
#
# $$ p_{Hg}=\rho_{Hg} \cdot g \cdot h_{Hg}$$
# $$p_{water}=\rho_{water} \cdot g \cdot h_{water}$$
# $$p_{water}=p_{Hg}$$
# $$\rho_{water} \cdot g \cdot h_{water}=\rho_{Hg}  \cdot g \cdot h_{Hg}$$
#
# Then, solving for $h_{water}$, we obtain:
#
# $$h_{water}=\frac{\rho_{Hg} \cdot g \cdot h_{Hg}}{\rho_{water} \cdot g}$$
#
# $$h_{water}=\frac{\rho_{Hg} \cdot  h_{Hg}}{\rho_{water} }$$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_A= p_B-rho_water*g*h_3+rho_water*g*h_1+rho_oil*g*h_2 #Pa
# h_water= (rho_Hg_/rho_water)*h_Hg #m
# p_A_abs= p_A/(rho_water*g)+h_water #m abs
# Out:
# \[
# \begin{aligned}
# p_{A} &= p_{B} - \rho_{water} \cdot g \cdot h_{3} + \rho_{water} \cdot g \cdot h_{1} + \rho_{oil} \cdot g \cdot h_{2} \\&= 50000 - 1000 \cdot 9.81 \cdot 0.60 + 1000 \cdot 9.81 \cdot 0.30 + 800.00 \cdot 9.81 \cdot 0.20 \\&= 48626.60 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# h_{water} &= \left( \frac{ \rho_{Hg_{}} }{ \rho_{water} } \right) \cdot h_{Hg} \\&= \left( \frac{ 13600 }{ 1000 } \right) \cdot 0.73 \\&= 9.93 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# p_{A_{abs}} &= \frac{ p_{A} }{ \rho_{water} \cdot g } + h_{water} \\&= \frac{ 48626.60 }{ 1000 \cdot 9.81 } + 9.93 \\&= 14.88 \; \;\textrm{(m abs)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 12 (***)[R]

# %% [markdown]
# Calculate the pressure at A in the figure below. Work from basic principles. Assume ρ<sub>Hg</sub> = 13550 kg/m<sup>3</sup>. {-12.8 kPa}

# %%
from PIL import Image
img = Image.open(r"figures/50.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=503x226 at 0x1D0C2286430>

# %% [markdown]
# **Given:**

# %%
# %%render param
# rho_Hg_= 13550 #kg/m3
# h_water_tank=600 #mm
# h_water=200 #mm
# h_Hg= 140 #mm
# h_oil=90 #mm
# s_oil= 0.83
# Out:
# \[
# \begin{aligned}
# \rho_{Hg_{}} &= 13550 \; \;\textrm{(kg/m3)}
#  &h_{water_{tank}} &= 600 \; \;\textrm{(mm)}
#  &h_{water} &= 200 \; \;\textrm{(mm)}
# \\[10pt]
#  h_{Hg} &= 140 \; \;\textrm{(mm)}
#  &h_{oil} &= 90 \; \;\textrm{(mm)}
#  &s_{oil} &= 0.830 \;
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %%
from PIL import Image
img = Image.open(r"figures/50s.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=981x463 at 0x1D0C241C610>

# %% [markdown]
# ```{toggle}
# Considering that the same fluid at the same height has the same pressure, the following point has equal pressures $p_1=p_2$
#
# $$
# p_3= \rho_{water} \cdot g \cdot h_{water tank}-\rho_{water} \cdot g \cdot h_{water}\\
# $$
#
# $$
# p_1= p_3-\rho_{Hg}\cdot g \cdot h_{Hg}\\
# $$
#
# $$
# p_4= p_A- \rho_{oil} \cdot g \cdot h_{oil}\\
# $$
#
# $$
# p_2= p_4- \rho_{oil} \cdot g \cdot h_{oil Hg}\\
# $$
#
# Using the equation the pressure in A can be calcualted
#
# $$
# \rho_{water} \cdot g \cdot h_{water tank}-\rho_{water} \cdot g \cdot h_{water}-\rho_{Hg} \cdot g \cdot h_{Hg}=p_A- \rho_{oil} \cdot g \cdot h_{oil}- \rho_{oil} \cdot g \cdot h_{oil Hg}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# rho_oil=s_oil*rho_water # kg/m3
# p_A= rho_water*g*(h_water_tank-h_water)/1000-rho_Hg_*g*h_Hg/1000 +rho_oil*g*(h_oil+h_Hg)/1000 #Pa
# p_A_abs= p_A+ p_atm #Pa
# Out:
# \[
# \begin{aligned}
# \rho_{oil} &= 830.000 \; \;\textrm{(kg/m3)}
# \\[10pt]
# p_{A} &= \rho_{water} \cdot g \cdot \frac{ h_{water_{tank}} - h_{water} }{ 1000 } - \rho_{Hg_{}} \cdot g \cdot \frac{ h_{Hg} }{ 1000 } + \rho_{oil} \cdot g \cdot \frac{ h_{oil} + h_{Hg} }{ 1000 } \\&= 1000 \cdot 9.810 \cdot \frac{ 600 - 200 }{ 1000 } - 13550 \cdot 9.810 \cdot \frac{ 140 }{ 1000 } + 830.000 \cdot 9.810 \cdot \frac{ 90 + 140 }{ 1000 } \\&= -12812.841 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{A_{abs}} &= p_{A} + p_{atm} \\&= -12812.841 + 101325 \\&= 88512.159 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 13 (**)

# %% [markdown]
# Both gauges in the figure below are calibrated to measure absolute pressure. The gauge A in the figure below reads 290 kPa abs. What is the height h of water? What does gauge B read? Assume ρ<sub>Hg</sub> = 13600 kg/m<sup>3</sup>. {2.23 m; 204 kPa abs}

# %%
from PIL import Image
img = Image.open(r"figures/51.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=436x280 at 0x1D0C246FD60>

# %% [markdown]
# **Given:**

# %%
# %%render param 1
# p_A=290000 #Pa
# rho_Hg_=13600 #kg/m3
# h_1=0.7 #m
# p_air=175000 #Pa abs
# Out:
# \[
# \begin{aligned}
# p_{A} &= 290000 \; \;\textrm{(Pa)}
#  &\rho_{Hg_{}} &= 13600 \; \;\textrm{(kg/m3)}
#  &h_{1} &= 0.7 \; \;\textrm{(m)}
# \\[10pt]
#  p_{air} &= 175000 \; \;\textrm{(Pa abs)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# Establishing that:
#
# $$p_A=\rho_{Hg} \cdot g \cdot h_1+\rho_{water} \cdot g  \cdot h +p_{air}$$
#
# We can solve $h$:
#
# $$h=\frac{p_A-(\rho_{Hg} \cdot g \cdot h_1)-p_{air}}{\rho_{water} \cdot g}$$
#
# Then, the pressure at B can be calculated as:
#
# $$p_B=p_{air}+\rho_{water} \cdot g \cdot (h+h_1)$$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h= (p_A-rho_Hg_*g*h_1-p_air)/(rho_water*g) #m
# p_B= p_air+rho_water*g*(h_1+h) #Pa
# p_B_= p_B/1000 #kPa
# Out:
# \[
# \begin{aligned}
# h &= \frac{ p_{A} - \rho_{Hg_{}} \cdot g \cdot h_{1} - p_{air} }{ \rho_{water} \cdot g } \\&= \frac{ 290000 - 13600 \cdot 9.81 \cdot 0.70 - 175000 }{ 1000 \cdot 9.81 } \\&= 2.20 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# p_{B} &= p_{air} + \rho_{water} \cdot g \cdot \left( h_{1} + h \right) \\&= 175000 + 1000 \cdot 9.81 \cdot \left( 0.70 + 2.20 \right) \\&= 203475.80 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{B_{}} &= \frac{ p_{B} }{ 1000 } \\&= \frac{ 203475.80 }{ 1000 } \\&= 203.48 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ## Problems for Lecture 6 and 7: Forces on plane surfaces

# %% [markdown]
# ### Force on a plane surface -uniform pressure distribution

# %% [markdown]
# ---
# #### Question 1 (**)

# %% [markdown]
# A force of 460 N is exerted on lever AB, as shown in the figure below. End B is connected to a piston which fits into a cylinder having a diameter of 60 mm. What force FD acts on the large piston if the volume between C and D is filled with air? {15.8 kN}

# %%
img = Image.open(r"figures/52.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=654x290 at 0x1D0C24DCCA0>

# %% [markdown]
# **Given:**

# %%
# %%render param
# F_A=460 #N
# d_C=0.06 #m
# d_D=0.26 #m
# L_A=0.22 #m
# L_C=0.12 #m
# Out:
# \[
# \begin{aligned}
# F_{A} &= 460 \; \;\textrm{(N)}
#  &d_{C} &= 0.060 \; \;\textrm{(m)}
#  &d_{D} &= 0.260 \; \;\textrm{(m)}
# \\[10pt]
#  L_{A} &= 0.220 \; \;\textrm{(m)}
#  &L_{C} &= 0.120 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# Given that a force Fa is applied at point A of the lever AB, the lever exerts a moment about the pivot. To maintain equilibrium, the moments around the pivot must balance, meaning that the momentum applied at point A has to be equal to the momentum applied at point C. Considering that momentum is force times the distance the following equation can be used.
#
# $$
# \sum M=0\\
# $$
#
# $$
# F_C \cdot L_C-F_A \cdot L_A=0\\
# $$
#
# $$
# F_C \cdot L_C=F_A \cdot L_A
# $$
#
# The cylinder between points C and D is filled with air, which means pressure is transmitted evenly throughout the system. Considering that $F=p \cdot A$ the following relationship can be used
#
# $$
# P_C=P_D\\
# $$
#
# $$
# F_C/A_C=F_D/A_D
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# F_C= F_A*(L_A/L_C) #N
# A_C= pi*(d_C/2)**2 #m2
# A_D= pi*(d_D/2)**2 #m2
# F_D= (F_C/A_C)*A_D #N
# Out:
# \[
# \begin{aligned}
# F_{C} &= F_{A} \cdot \left( \frac{ L_{A} }{ L_{C} } \right) \\&= 460 \cdot \left( \frac{ 0.220 }{ 0.120 } \right) \\&= 843.333 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# A_{C} &= \pi \cdot \left( \frac{ d_{C} }{ 2 } \right) ^{ 2 } \\&= 3.142 \cdot \left( \frac{ 0.060 }{ 2 } \right) ^{ 2 } \\&= 0.003 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# A_{D} &= \pi \cdot \left( \frac{ d_{D} }{ 2 } \right) ^{ 2 } \\&= 3.142 \cdot \left( \frac{ 0.260 }{ 2 } \right) ^{ 2 } \\&= 0.053 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F_{D} &= \left( \frac{ F_{C} }{ A_{C} } \right) \cdot A_{D} \\&= \left( \frac{ 843.333 }{ 0.003 } \right) \cdot 0.053 \\&= 15835.926 \; \;\textrm{(N)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2 (**)

# %% [markdown]
# For the configuration shown below, calculate the weight of the piston if the gauge pressure reading is 70 kPa. { 61.6 kN}

# %%
img = Image.open(r"figures/53.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=652x499 at 0x21F15D6E760>

# %% [markdown]
# **Given:**

# %%
# %%render param 2
# p_gauge= 70000 #Pa
# h_m=1 #m
# S_oil=0.86
# d=1 #m
# Out:
# \[
# \begin{aligned}
# p_{gauge} &= 70000 \; \;\textrm{(Pa)}
#  &h_{m} &= 1 \; \;\textrm{(m)}
#  &S_{oil} &= 0.86 \;
# \\[10pt]
#  d &= 1 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# Since the system is in equilibrium, the force of the piston weight must be equal to the force exerted by the oil. This can be stated by the following equations:
#
# $$ \sum F=0 $$
#
# $$
# -W+F_x=0
# $$
#
# $$ W=F_x $$
#
# Additionally, considering that $F=p A$, the equation is:
#
# $$ W=p \cdot A $$
#
# Note that the gauge pressure is one meter above the base of the piston.Therefore, the pressure at the base is equal to the pressure read by the gauge pressure plus the pressure exerted by the oil in the 1-meter column between the gauge and the piston's base:
#
# $$ W=(p_{gauge} + p_1) \cdot A $$
#
# Where $p_1$ can be calculated as:
#
# $$ p_1=\rho_{oil} \cdot g \cdot h $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# A= pi*d**2/4 #m2
# rho_oil= S_oil*rho_water #kg/m3
# W= (p_gauge+rho_oil*g*h_m)*A #N
# W_ = W/1000 #kN
# Out:
# \[
# \begin{aligned}
# A &= \pi \cdot \frac{ \left( d \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 1 \right) ^{ 2 } }{ 4 } \\&= 0.79 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# \rho_{oil} &= S_{oil} \cdot \rho_{water} \\&= 0.86 \cdot 1000 \\&= 860.00 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# W &= \left( p_{gauge} + \rho_{oil} \cdot g \cdot h_{m} \right) \cdot A \\&= \left( 70000 + 860.00 \cdot 9.81 \cdot 1 \right) \cdot 0.79 \\&= 61603.96 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# W_{} &= \frac{ W }{ 1000 } \\&= \frac{ 61603.96 }{ 1000 } \\&= 61.60 \; \;\textrm{(kN)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Hydrostatic force on a vertical plane surface

# %% [markdown]
# ---
# #### Question 3 (*)[R]

# %% [markdown]
# A rectangular plate submerged vertically in water is 5 by 4 m, the 5-m side being horizontal and the 4-m side vertical. Determine the magnitude of the force on one side of the plate and the depth to its centre of action if the top edge of the plate is a) at the water surface and b) 1 m below the water surface. Use both the ‘volume under the pressure distribution’ and moment-area methods. {392 kN at 2.67 m; 589 kN at 3.44 m}

# %% [markdown]
# **Given:**

# %%
# %%render param
# b= 5 #m
# h= 4 #m
# Out:
# \[
# \begin{aligned}
# b &= 5 \; \;\textrm{(m)}
#  &h &= 4 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The magnitude of the force is determined with the following equation:
#
# $$F= \rho_{liquid} \cdot g \cdot h_c \cdot A$$
#
# and the depth to its centre of action is
#
# $$
# y_p = \frac {A \cdot y_c^2 +I_c}{A \cdot y_c}
# $$
#
# Since it is a rectangle, the following equations can be used:
#
# $$
# h_c=h /2\\
# $$
#
# $$
# A= b \cdot h\\
# $$
#
# $$
# I_c= \frac {b \cdot h^3}{12}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h_c= h/2 #m
# A= b*h #m2
# F= (rho_water*g*h_c*A)/1000 #kN
# y_c= h_c #m
# I_c= (b*h**3)/12 #m4
# y_p= (A*y_c**2+I_c)/(y_c*A) #m
# Out:
# \[
# \begin{aligned}
# h_{c} &= \frac{ h }{ 2 } \\&= \frac{ 4 }{ 2 } \\&= 2.00 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= b \cdot h \\&= 5 \cdot 4 \\&= 20 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F &= \frac{ \rho_{water} \cdot g \cdot h_{c} \cdot A }{ 1000 } \\&= \frac{ 1000 \cdot 9.81 \cdot 2.00 \cdot 20 }{ 1000 } \\&= 392.40 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# y_{c} &= 2.00 \; \;\textrm{(m)}
# \\[10pt]
# I_{c} &= \frac{ b \cdot \left( h \right) ^{ 3 } }{ 12 } \\&= \frac{ 5 \cdot \left( 4 \right) ^{ 3 } }{ 12 } \\&= 26.67 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p} &= \frac{ A \cdot \left( y_{c} \right) ^{ 2 } + I_{c} }{ y_{c} \cdot A } \\&= \frac{ 20 \cdot \left( 2.00 \right) ^{ 2 } + 26.67 }{ 2.00 \cdot 20 } \\&= 2.67 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# The same procedure is performed, except that this time the depth below the surface is included to calculate the centroid.

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# depth=1 #m
# h_c= h/2+depth #m
# F= (rho_water*g*h_c*A)/1000 #kN
# y_c= h/2+depth #m
# y_p= (A*y_c**2+I_c)/(y_c*A) #m
# Out:
# \[
# \begin{aligned}
# \mathrm{depth} &= 1 \; \;\textrm{(m)}
# \\[10pt]
# h_{c} &= \frac{ h }{ 2 } + \mathrm{depth} \\&= \frac{ 4 }{ 2 } + 1 \\&= 3.00 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# F &= \frac{ \rho_{water} \cdot g \cdot h_{c} \cdot A }{ 1000 } \\&= \frac{ 1000 \cdot 9.81 \cdot 3.00 \cdot 20 }{ 1000 } \\&= 588.60 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# y_{c} &= \frac{ h }{ 2 } + \mathrm{depth} \\&= \frac{ 4 }{ 2 } + 1 \\&= 3.00 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# y_{p} &= \frac{ A \cdot \left( y_{c} \right) ^{ 2 } + I_{c} }{ y_{c} \cdot A } \\&= \frac{ 20 \cdot \left( 3.00 \right) ^{ 2 } + 26.67 }{ 3.00 \cdot 20 } \\&= 3.44 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 4 (*)

# %% [markdown]
# A vertical plane surface is circular with a diameter of 2 m. If its top edge is 0.5 m below the water surface, find the magnitude of the force on one side of the surface and the depth at which it acts. {46.2 kN at 1.67 m}

# %% [markdown]
# **Given:**

# %%
# %%render param
# d=2 #m
# h_below=0.5 #m
# Out:
# \[
# \begin{aligned}
# d &= 2 \; \;\textrm{(m)}
#  &h_{below} &= 0.500 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The magnitude of the force can be calculated as:
#
# $$ F=\rho g h_c A $$
#
# And the depth at which it acts can be calculated as:
#
# $$ y_p= y_c+ \frac{I_x}{y_c A}$$
#
# Where $y_c$ is the distance from the surface of the water to the centroid (in this case: $r+h_{below}$), A is the area of the surface (in this case a circle), and  $I_x$ is the second moment of inertia, which for a circular area is:
#
# $$ I_y = \frac{\pi r^4}{4} $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# r= d/2 #m
# F_mag= rho_water*g*(r+h_below)*pi*d**2/4 #N
# F_mag_= F_mag/1000 #kN
#
# I_x= pi*(d/2)**4/4 #m4
# y_c= r+h_below #m
# A= pi*d**2/4 #m2
# y_p= y_c+I_x/(y_c*A) #m
# Out:
# \[
# \begin{aligned}
# r &= \frac{ d }{ 2 } \\&= \frac{ 2 }{ 2 } \\&= 1.00 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# F_{mag} &= \rho_{water} \cdot g \cdot \left( r + h_{below} \right) \cdot \pi \cdot \frac{ \left( d \right) ^{ 2 } }{ 4 } \\&= 1000 \cdot 9.81 \cdot \left( 1.00 + 0.50 \right) \cdot 3.14 \cdot \frac{ \left( 2 \right) ^{ 2 } }{ 4 } \\&= 46228.54 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# F_{mag_{}} &= \frac{ F_{mag} }{ 1000 } \\&= \frac{ 46228.54 }{ 1000 } \\&= 46.23 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# I_{x} &= \pi \cdot \frac{ \left( \frac{ d }{ 2 } \right) ^{ 4 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( \frac{ 2 }{ 2 } \right) ^{ 4 } }{ 4 } \\&= 0.79 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{c} &= r + h_{below} \\&= 1.00 + 0.50 \\&= 1.50 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \frac{ \left( d \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 2 \right) ^{ 2 } }{ 4 } \\&= 3.14 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# y_{p} &= y_{c} + \frac{ I_{x} }{ y_{c} \cdot A } \\&= 1.50 + \frac{ 0.79 }{ 1.50 \cdot 3.14 } \\&= 1.67 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 5 (**)

# %% [markdown]
# A water tank is pressurized to 85 cm Hg as shown below. Determine the size of the hydrostatic force per meter width on panel AB, as well as its centre of pressure. {502 kN}

# %%
img = Image.open(r"figures/56.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=299x315 at 0x1D0C24BE760>

# %% [markdown]
# **Given:**

# %%
# %%render param
# p= 85 #cm Hg
# h_1= 2#m
# h_2= 4 #m
# h_3= 3 #m
# h_5= 0.85 #m
# Out:
# \[
# \begin{aligned}
# p &= 85 \; \;\textrm{(cm Hg)}
#  &h_{1} &= 2 \; \;\textrm{(m)}
#  &h_{2} &= 4 \; \;\textrm{(m)}
# \\[10pt]
#  h_{3} &= 3 \; \;\textrm{(m)}
#  &h_{5} &= 0.850 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The size of the hydrostatic force is $F= p \cdot A$ and the $p_{AB}$ is
#
# $$
# p_{AB}= p_{Hg}+p_{water}
# $$
#
# The water pressure and mercury pressure can be calculated as: $p=\rho_{liquid} \cdot g \cdot h$
#
# $$
# F= p \cdot A\\
# $$
#
# As it is the force per metre width on panel, it can be asumed that the width is 1 m.
#
# $$
# F= p \cdot (bh)
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# p_Hg= rho_Hg*g*h_5 #Pa
# p_water= rho_water*g*(h_2+(h_3)/2) #Pa
# p_AB= p_Hg+p_water #Pa
# F_b= p_AB*h_3/1000 #kN
# Out:
# \[
# \begin{aligned}
# p_{Hg} &= \rho_{Hg} \cdot g \cdot h_{5} \\&= 13600 \cdot 9.8 \cdot 0.8 \\&= 113403.6 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{water} &= \rho_{water} \cdot g \cdot \left( h_{2} + \frac{ h_{3} }{ 2 } \right) \\&= 1000 \cdot 9.8 \cdot \left( 4 + \frac{ 3 }{ 2 } \right) \\&= 53955.0 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{AB} &= p_{Hg} + p_{water} \\&= 113403.6 + 53955.0 \\&= 167358.6 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# F_{b} &= p_{AB} \cdot \frac{ h_{3} }{ 1000 } \\&= 167358.6 \cdot \frac{ 3 }{ 1000 } \\&= 502.1 \; \;\textrm{(kN)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Hydrostatic force on a plane surface

# %% [markdown]
# ---
# #### Question 6 (*)

# %% [markdown]
# A flat plate is used to close a rectangular opening in a large water tank as shown below. The plate is 3 m wide and 4 m long. What is the magnitude and position of the resultant force of the water on the plate? {605.4 kN at 2.166 m from top of gate along its length}

# %%
from PIL import Image
img = Image.open(r"figures/57.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=324x202 at 0x276B899EB50>

# %% [markdown]
# **Given:**

# %%
# %%render param
# B=3 #m
# L_p=4 #m
# theta=40 #°
# L=6 #m
# Out:
# \[
# \begin{aligned}
# B &= 3 \; \;\textrm{(m)}
#  &L_{p} &= 4 \; \;\textrm{(m)}
#  &\theta &= 40 \; \;\textrm{(°)}
# \\[10pt]
#  L &= 6 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The magnitud of the force can be calculated as follows:
#
# $$
# F=\rho \cdot g \cdot A \cdot h_c\\
# F=\rho \cdot g \cdot A \cdot y_c \cdot sen(\theta)
# $$
#
# And the position of the resultant force is:
#
# $$y_p = y_c + \frac{I_x}{y_c \cdot A}$$
#
# Where:
#
# $$
# I_x = \frac{b \cdot h^3}{12}
# $$
#
# $$
# y_c= L_m + \frac{L_p}{2}
# $$
#
# Additionally, the position of the resultant force from the gate is equal to $y_p$ minus $L$
#
# $$
# y_{gate}= y_p-L
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# y_c= L+L_p/2 #m
# F_= rho_water*g*y_c*(B*L_p)*sin(radians(theta)) #N
#
# I_x = (B*L_p**3)/12 #m4
# A_= B*L_p #m2
# y_c= L+L_p/2 #m
# y_p_=y_c +I_x/(y_c*A_) #m
# y_gate= y_p_-L #m
# Out:
# \[
# \begin{aligned}
# y_{c} &= L + \frac{ L_{p} }{ 2 } \\&= 6 + \frac{ 4 }{ 2 } \\&= 8.00 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# F_{} &= \rho_{water} \cdot g \cdot y_{c} \cdot \left( B \cdot L_{p} \right) \cdot \sin { \left( \operatorname{radians} \theta \right) } \\&= 1000 \cdot 9.81 \cdot 8.00 \cdot \left( 3 \cdot 4 \right) \cdot \sin { \left( \operatorname{radians} 40 \right) } \\&= 605351.66 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# I_{x} &= \frac{ B \cdot \left( L_{p} \right) ^{ 3 } }{ 12 } \\&= \frac{ 3 \cdot \left( 4 \right) ^{ 3 } }{ 12 } \\&= 16.00 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# A_{} &= B \cdot L_{p} \\&= 3 \cdot 4 \\&= 12 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# y_{c} &= L + \frac{ L_{p} }{ 2 } \\&= 6 + \frac{ 4 }{ 2 } \\&= 8.00 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# y_{p_{}} &= y_{c} + \frac{ I_{x} }{ y_{c} \cdot A_{} } \\&= 8.00 + \frac{ 16.00 }{ 8.00 \cdot 12 } \\&= 8.17 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# y_{gate} &= y_{p_{}} - L \\&= 8.17 - 6 \\&= 2.17 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 7 (*)

# %% [markdown]
# A section through a container holding water is shown below. One of the container’s panels is angled at 55° to the horizon and contains a circular gate with a diameter of 2 m. The water is 4 m deep at the top of the gate.  Calculate the size of the resultant force of the water on the gate, as well as its centre of pressure. {148.5 kN; 1.04 m from the top along the gate}

# %%
img = Image.open(r"figures/58.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=752x255 at 0x1D0C24BE190>

# %% [markdown]
# **Given:**

# %%
# %%render param
# h=4 #m
# d=2 #m
# theta=55 #°
# Out:
# \[
# \begin{aligned}
# h &= 4 \; \;\textrm{(m)}
#  &d &= 2 \; \;\textrm{(m)}
#  &\theta &= 55 \; \;\textrm{(°)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The magnitude of the force is determined with the following equation:
#
# $$
# F= \rho_{liquid} \cdot g \cdot h_c \cdot A
# $$
#
# and the depth to its centre of action is
#
# $$
# y_p = \frac {A \cdot y_c^2 +I_c}{A \cdot y_c}
# $$
#
# Since it is a circle, the following equations can be used:
#
# $$
# h_c=h + sin (\theta) \cdot d/2\\
# $$
#
# $$
# A= \pi R^2\\
# $$
#
# $$
# I_c= \frac {\pi R^4} {4}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h_c= h+sin(radians(theta))*d/2 #m
# A= pi*(d/2)**2 #m2
# F= rho_water*g*h_c*A/1000 #kN
# y_surface= h/sin(radians(theta)) #m
# y_c= d/2+y_surface #m
# I_c= (pi*(d/2)**4)/4 #m4
# y_p= (A*y_c**2+I_c)/(y_c*A) #m
# y_p_= y_p-y_surface #m (from the top along the gate)
# Out:
# \[
# \begin{aligned}
# h_{c} &= h + \sin { \left( \operatorname{radians} \theta \right) } \cdot \frac{ d }{ 2 } \\&= 4 + \sin { \left( \operatorname{radians} 135 \right) } \cdot \frac{ 2 }{ 2 } \\&= 4.71 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \left( \frac{ d }{ 2 } \right) ^{ 2 } \\&= 3.14 \cdot \left( \frac{ 2 }{ 2 } \right) ^{ 2 } \\&= 3.14 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F &= \rho_{water} \cdot g \cdot h_{c} \cdot \frac{ A }{ 1000 } \\&= 1000 \cdot 9.81 \cdot 4.71 \cdot \frac{ 3.14 }{ 1000 } \\&= 145.07 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# y_{surface} &= \frac{ h }{ \sin { \left( \operatorname{radians} \theta \right) } } \\&= \frac{ 4 }{ \sin { \left( \operatorname{radians} 135 \right) } } \\&= 5.66 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# y_{c} &= \frac{ d }{ 2 } + y_{surface} \\&= \frac{ 2 }{ 2 } + 5.66 \\&= 6.66 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# I_{c} &= \frac{ \pi \cdot \left( \frac{ d }{ 2 } \right) ^{ 4 } }{ 4 } \\&= \frac{ 3.14 \cdot \left( \frac{ 2 }{ 2 } \right) ^{ 4 } }{ 4 } \\&= 0.79 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p} &= \frac{ A \cdot \left( y_{c} \right) ^{ 2 } + I_{c} }{ y_{c} \cdot A } \\&= \frac{ 3.14 \cdot \left( 6.66 \right) ^{ 2 } + 0.79 }{ 6.66 \cdot 3.14 } \\&= 6.69 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# y_{p_{}} &= y_{p} - y_{surface} \\&= 6.69 - 5.66 \\&= 1.04 \; \;\textrm{(m (from the top along the gate))}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 8 (*)

# %% [markdown]
# The container shown in the figure below has a width of 5 m into the screen and is filled with water. A panel BC with cross-sectional shape as shown is installed in one wall. The distances AB and BC are 4 m and 2 m respectively, and the angle θ is 135°. Calculate the resultant force of the water on panel BC and its centre of pressure. {109 kN; 1.05 m from B on BC}

# %%
from PIL import Image
img = Image.open(r"figures/59.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=263x113 at 0x276B89CD2E0>

# %% [markdown]
# **Given:**

# %%
# %%render param
# B=5 #m
# AB= 4#m
# BC= 2#m
# theta = 135 #°
# theta_rad = (radians(theta)) #radians
# Out:
# \[
# \begin{aligned}
# B &= 5 \; \;\textrm{(m)}
#  &\mathrm{AB} &= 4 \; \;\textrm{(m)}
#  &\mathrm{BC} &= 2 \; \;\textrm{(m)}
# \\[10pt]
#  \theta &= 135 \; \;\textrm{(°)}
#  &\theta_{rad} &= 2.356 \; \;\textrm{(radians)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The magnitude of the force is determined with the following equation:
#
# $$F= \rho_{liquid} \cdot g \cdot h_c \cdot A$$
#
# and the depth to its centre of action is $y_p = y_c + \frac{I_x}{y_c \cdot A}$
#
# Since it is a circle, the following equations can be used:
#
# $$
# h_c=y_c sin (\theta)\\
# $$
#
# $$
# A= \pi r^2\\
# $$
#
# $$
# I_c= \frac {\pi r^4} {4}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# y_c_= AB+BC/2 #m
# A= pi*BC**2/4 #m2
# F_= rho_water*g*y_c_*A*sin(theta_rad)/1000 #kN
#
# r=BC/2
# I_x = pi*r**4/4 #m4
# y_p=y_c_ +I_x/(y_c_*A) #m
# y_forceB= y_p-AB #m (from B on BC)
# h_p= y_p_*sin(theta_rad) #m (vertical from water surface to the force)
# Out:
# \[
# \begin{aligned}
# y_{c_{}} &= \mathrm{AB} + \frac{ \mathrm{BC} }{ 2 } \\&= 4 + \frac{ 2 }{ 2 } \\&= 5.00 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \frac{ \left( \mathrm{BC} \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 2 \right) ^{ 2 } }{ 4 } \\&= 3.14 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F_{} &= \rho_{water} \cdot g \cdot y_{c_{}} \cdot A \cdot \frac{ \sin \left( \theta_{rad} \right) }{ 1000 } \\&= 1000 \cdot 9.81 \cdot 5.00 \cdot 3.14 \cdot \frac{ \sin \left( 2.36 \right) }{ 1000 } \\&= 108.96 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# r &= 1.00 \;
# \\[10pt]
# I_{x} &= \pi \cdot \frac{ \left( r \right) ^{ 4 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 1.00 \right) ^{ 4 } }{ 4 } \\&= 0.79 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p} &= y_{c_{}} + \frac{ I_{x} }{ y_{c_{}} \cdot A } \\&= 5.00 + \frac{ 0.79 }{ 5.00 \cdot 3.14 } \\&= 5.05 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# y_{forceB} &= y_{p} - \mathrm{AB} \\&= 5.05 - 4 \\&= 1.05 \; \;\textrm{(m (from B on BC))}\\[10pt]
# \\[10pt]
# h_{p} &= y_{p_{}} \cdot \sin \left( \theta_{rad} \right) \\&= 17.27 \cdot \sin \left( 2.36 \right) \\&= 12.21 \; \;\textrm{(m (vertical from water surface to the force))}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 9 (*)[R]

# %% [markdown]
# The container shown in the figure below has a width of 5 m into the page and is filled with water. A panel BC with cross-sectional shape as shown is installed in one wall. The distances AB and BC are 4 m and 2 m respectively, b is 2 m and the angle θ is 135°. Calculate the resultant force of the water on panel BC and its centre of pressure.  {64.7 kN; 0.71 m from B on BC}

# %%
img = Image.open(r"figures/60.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=511x216 at 0x1D0C2526F40>

# %% [markdown]
# **Given:**

# %%
# %%render param
# B=5 #m
# y_AB=4 #m
# y_BC=2 #m
# b=2 #m
# theta=135 #°
# Out:
# \[
# \begin{aligned}
# B &= 5 \; \;\textrm{(m)}
#  &y_{AB} &= 4 \; \;\textrm{(m)}
#  &y_{BC} &= 2 \; \;\textrm{(m)}
# \\[10pt]
#  b &= 2 \; \;\textrm{(m)}
#  &\theta &= 135 \; \;\textrm{(°)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The magnitude of the force is determined with the following equation:
#
# $$F= \rho_{liquid} \cdot g \cdot h_c \cdot A$$
#
# and the depth to its centre of action is
#
# $$
# y_p = \frac {A \cdot y_c^2 +I_c}{A \cdot y_c}
# $$
#
# Since it is a triangle, the following equations can be used:
#
# $$
# h_c= y_c sin(\alpha)\\
# $$
#
# $$
# y_c=y_{AB}+\frac{y_{BC}}{3}\\
# $$
#
# $$
# A= b \cdot h/2\\
# $$
#
# $$
# I_c= \frac {b \cdot h^3}{36}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# A= (b*y_BC)/2 #m2
# alpha= 180-theta #°
# y_c= y_AB+(y_BC/3) #m
# h_c= sin(radians(alpha))*(y_c) #m
# F= rho_water*g*h_c*A #N
# I_c= (b*y_BC**3)/36 #m4
# y_p= y_c+I_c/(y_c*A) #m from A
# y_p_= y_p-y_AB #m from B
# Out:
# \[
# \begin{aligned}
# A &= \frac{ b \cdot y_{BC} }{ 2 } \\&= \frac{ 2 \cdot 2 }{ 2 } \\&= 2.00 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# \alpha &= 180 - \theta \\&= 180 - 135 \\&= 45 \; \;\textrm{(°)}\\[10pt]
# \\[10pt]
# y_{c} &= y_{AB} + \left( \frac{ y_{BC} }{ 3 } \right) \\&= 4 + \left( \frac{ 2 }{ 3 } \right) \\&= 4.67 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# h_{c} &= \sin { \left( \operatorname{radians} \alpha \right) } \cdot y_{c} \\&= \sin { \left( \operatorname{radians} 45 \right) } \cdot 4.67 \\&= 3.30 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# F &= \rho_{water} \cdot g \cdot h_{c} \cdot A \\&= 1000 \cdot 9.81 \cdot 3.30 \cdot 2.00 \\&= 64742.70 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# I_{c} &= \frac{ b \cdot \left( y_{BC} \right) ^{ 3 } }{ 36 } \\&= \frac{ 2 \cdot \left( 2 \right) ^{ 3 } }{ 36 } \\&= 0.44 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p} &= y_{c} + \frac{ I_{c} }{ y_{c} \cdot A } \\&= 4.67 + \frac{ 0.44 }{ 4.67 \cdot 2.00 } \\&= 4.71 \; \;\textrm{(m from A)}\\[10pt]
# \\[10pt]
# y_{p_{}} &= y_{p} - y_{AB} \\&= 4.71 - 4 \\&= 0.71 \; \;\textrm{(m from B)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 10 (*)

# %% [markdown]
# The container shown in the figure below has a width of 5 m into the screen and is filled with water. A panel BC with cross-sectional shape as shown is installed in one wall. The distances AB and BC are 3 m and 1 m respectively, and the angle θ is 120°. Calculate the resultant force of the water on panel BC and its centre of pressure. {47.72 kN; 0.6 m from B on BC}

# %%
from PIL import Image
img = Image.open(r"figures/61.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=315x159 at 0x21F15CBEFA0>

# %% [markdown]
# **Given:**

# %%
# %%render param
# B_=5 #m
# AB= 3#m
# BC= 1#m
# theta = 120 #°
# theta_rad = (radians(theta)) #radians
# Out:
# \[
# \begin{aligned}
# B_{} &= 5 \; \;\textrm{(m)}
#  &\mathrm{AB} &= 3 \; \;\textrm{(m)}
#  &\mathrm{BC} &= 1 \; \;\textrm{(m)}
# \\[10pt]
#  \theta &= 120 \; \;\textrm{(°)}
#  &\theta_{rad} &= 2.094 \; \;\textrm{(radians)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The magnitude of the force is determined with the following equation:
#
# $$F= \rho_{liquid} \cdot g \cdot h_c \cdot A$$
#
# Where:
#
# $$ h_c=y_c sin(\theta)$$
#
# $$ y_c=AB+BC- \frac{4r}{3\pi}$$
#
#
# and the depth to its centre of action is $y_p = y_c + \frac{I_x}{y_c \cdot A}$
#
#
# Since it is a semi circular area, the following equations can be used:
#
# $$ I_x= (\frac{\pi}{8} - \frac{8}{9\pi}) r^4$$
#
# $$A=\frac{\pi r^2}{2}$$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
#
# y_c_= AB+BC-4*BC/(3*pi) #m
# A= pi*BC**2/2 #m2
# F_= rho_water*g*y_c_*A*sin(theta_rad) #N
# I_x = 0.1098*BC**4 #m4
# y_p_=y_c_ +I_x/(y_c_*A) #m
# y_forceB= y_p_-AB #m (from B to on BC)
# h_p= y_p_*sin(theta_rad) #m (vertical distance from water surface to the force)
# Out:
# \[
# \begin{aligned}
# y_{c_{}} &= \mathrm{AB} + \mathrm{BC} - 4 \cdot \frac{ \mathrm{BC} }{ 3 \cdot \pi } \\&= 3 + 1 - 4 \cdot \frac{ 1 }{ 3 \cdot 3.14 } \\&= 3.58 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \frac{ \left( \mathrm{BC} \right) ^{ 2 } }{ 2 } \\&= 3.14 \cdot \frac{ \left( 1 \right) ^{ 2 } }{ 2 } \\&= 1.57 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F_{} &= \rho_{water} \cdot g \cdot y_{c_{}} \cdot A \cdot \sin \left( \theta_{rad} \right) \\&= 1000 \cdot 9.81 \cdot 3.58 \cdot 1.57 \cdot \sin \left( 2.09 \right) \\&= 47716.31 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# I_{x} &= 0.1098 \cdot \left( \mathrm{BC} \right) ^{ 4 } \\&= 0.1098 \cdot \left( 1 \right) ^{ 4 } \\&= 0.11 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p_{}} &= y_{c_{}} + \frac{ I_{x} }{ y_{c_{}} \cdot A } \\&= 3.58 + \frac{ 0.11 }{ 3.58 \cdot 1.57 } \\&= 3.60 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# y_{forceB} &= y_{p_{}} - \mathrm{AB} \\&= 3.60 - 3 \\&= 0.60 \; \;\textrm{(m (from B to on BC))}\\[10pt]
# \\[10pt]
# h_{p} &= y_{p_{}} \cdot \sin \left( \theta_{rad} \right) \\&= 3.60 \cdot \sin \left( 2.09 \right) \\&= 3.11 \; \;\textrm{(m (vertical distance from water surface to the force))}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 11 (**)[R]

# %% [markdown]
#  A 60 cm square gate has its top edge 12 m below the water surface. It is on a 45° angle and its bottom edge is hinged as shown below. What force P is needed to just open the gate? {21.42 kN}

# %%
img = Image.open(r"figures/62.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=301x226 at 0x1D0C247E280>

# %% [markdown]
# **Given:**

# %%
# %%render param 2
# A=0.6**2 #m2
# h=12 #m
# theta=45 #°
# Out:
# \[
# \begin{aligned}
# A &= 0.36 \; \;\textrm{(m2)}
#  &h &= 12 \; \;\textrm{(m)}
#  &\theta &= 45 \; \;\textrm{(°)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %%
img = Image.open(r"figures/62s.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=843x515 at 0x1D0C2526100>

# %% [markdown]
# ```{toggle}
# To calculate the force needed to open the gate, it is necessary to perform a moment balance between the hydrostatic force and the force needed to open the gate.
#
# $$
# \sum M = 0\\
# $$
#
# $$
# F_p \cdot L_p= F_{water} \cdot L_{water}\\
# $$
#
# To calculate the hydrostatic force the following equation should be used:
#
# $$F_{water}= \rho_{water} \cdot g \cdot h_c \cdot A$$
#
# Since the force is applied in a square shape, the following equations can be used:
#
# $$
# h_c=h + \frac {y \cdot sin (\theta)}{2}\\
# $$
#
# $$
# A= b \cdot h\\
# $$
#
# $$
# I_c= \frac {b \cdot h^3}{12}
# $$
#
# Considering that $h_c$ is the vertical measurement and $y_c$ is the inclination distance, the following procedure can be made:
#
# $$
# y_c= \frac {h_c}{sin(\theta)}\\
# $$
#
# Using the $y_c, I_c$ and $A$ the $y_p$ can be calculated using the following equation:
#
# $$y_p = \frac {Ay_c^2 +I_c}{Ay_c}$$
#
# After having the information, the momentum equation can be used considering the two forces applied in the hinge.
#
# $$
# \sum M = 0\\
# $$
#
# $$
# F_p \cdot L_p= F_{water} \cdot L_{water}\\
# $$
#
# Where:
#
# $L_p$ is the distance from the hinge to the point in which the force P is applied
#
# $L_{water}$ is the distance from the hinge to the point in which the hydrostatic force of the water is applied
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# y= sqrt(A) #m
# l= h/sin(radians(theta)) #m
# h_c= h+y*sin(radians(theta))/2 #m
# F_water= rho_water*g*h_c*A #N
# y_c= h_c/sin(radians(theta)) #,
# I_c= (y*y**3)/12 #m4
# y_p_= y_c+I_c/(y_c*A) #m from surface
# y_hinge_p= (l+y)-y_p_ #m from hinge
# F_p= F_water*y_hinge_p/y/1000 #kN
# Out:
# \[
# \begin{aligned}
# y &= \sqrt { A } \\&= \sqrt { 0.36 } \\&= 0.60 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# l &= \frac{ h }{ \sin { \left( \operatorname{radians} \theta \right) } } \\&= \frac{ 12 }{ \sin { \left( \operatorname{radians} 45 \right) } } \\&= 16.97 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# h_{c} &= h + y \cdot \frac{ \sin { \left( \operatorname{radians} \theta \right) } }{ 2 } \\&= 12 + 0.60 \cdot \frac{ \sin { \left( \operatorname{radians} 45 \right) } }{ 2 } \\&= 12.21 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# F_{water} &= \rho_{water} \cdot g \cdot h_{c} \cdot A \\&= 1000 \cdot 9.81 \cdot 12.21 \cdot 0.36 \\&= 43128.37 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# y_{c} &= \frac{ h_{c} }{ \sin { \left( \operatorname{radians} \theta \right) } } \\&= \frac{ 12.21 }{ \sin { \left( \operatorname{radians} 45 \right) } } \\&= 17.27 \; \;\textrm{(,)}\\[10pt]
# \\[10pt]
# I_{c} &= \frac{ y \cdot \left( y \right) ^{ 3 } }{ 12 } \\&= \frac{ 0.60 \cdot \left( 0.60 \right) ^{ 3 } }{ 12 } \\&= 0.01 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p_{}} &= y_{c} + \frac{ I_{c} }{ y_{c} \cdot A } \\&= 17.27 + \frac{ 0.01 }{ 17.27 \cdot 0.36 } \\&= 17.27 \; \;\textrm{(m from surface)}\\[10pt]
# \\[10pt]
# y_{hinge_{p}} &= \left( l + y \right) - y_{p_{}} \\&= \left( 16.97 + 0.60 \right) - 17.27 \\&= 0.30 \; \;\textrm{(m from hinge)}\\[10pt]
# \\[10pt]
# F_{p} &= F_{water} \cdot \frac{ y_{hinge_{p}} }{ y } \cdot \frac{1} { 1000 } \\&= 43128.37 \cdot \frac{ 0.30 }{ 0.60 } \cdot \frac{1} { 1000 } \\&= 21.44 \; \;\textrm{(kN)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 12 (***)

# %% [markdown]
# The figure below shows a plane pivot gate installed on a concrete dam. The gate is shown in its closed position. The vertical member (AB) has a length of hp = 3.0 m. The horizontal member (BC) has a length bp = 1.5 m. The width of the gate (into the paper) is lp = 10 m. The water level in the reservoir is located at a depth h above the gate’s pivot point (B). When the gate is in its closed position (as shown in the sketch), the gate seals watertight along C. At what depth h will the gate just start to open? {2.6 m}

# %%
from PIL import Image
img = Image.open(r"figures/63.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=557x547 at 0x21F15C0C7F0>

# %% [markdown]
# **Given:**

# %%
# %%render param 1
# l_p=10 #m
# h_p= 3#m
# b_p= 1.5#m
# theta = 120 #°
# Out:
# \[
# \begin{aligned}
# l_{p} &= 10 \; \;\textrm{(m)}
#  &h_{p} &= 3 \; \;\textrm{(m)}
#  &b_{p} &= 1.5 \; \;\textrm{(m)}
# \\[10pt]
#  \theta &= 120 \; \;\textrm{(°)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %%
from PIL import Image
img = Image.open(r"figures/63S.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=523x442>

# %% [markdown]
# ```{toggle}
# Moment around pivot point B
#
# $$
# \sum M= 0\\
# $$
#
# $$
# F_{AB} \cdot \frac{h}{3} + F_c \cdot b_p -F_{BC} \cdot \frac{b_p}{2}=0\\
# $$
#
# $$
# F_{AB}= \frac {\rho \cdot g \cdot h^2l_p}{2}\\
# $$
#
# $$
# F_{BC}= \rho \cdot g \cdot hb_p \cdot l_p
# $$
#
# Replacing $F_{AB}$ and $F_{BC}$
#
# $$
# \frac {\rho \cdot g \cdot h^2 \cdot l_p}{2} \cdot \frac{h}{3} + F_c \cdot b_p -\rho \cdot  g \cdot h \cdot b_p \cdot l_p \cdot \frac{b_p}{2}=0\\
# $$
#
# $$
# \rho \cdot  g \cdot h^2 \cdot l_p \cdot \frac{h}{6} + F_c \cdot b_p -\rho \cdot  g \cdot h \cdot b_p \cdot l_p \cdot \frac{b_p}{2}=0\\
# $$
#
# $F_C=0$ condition for gate opening
#
# $$
# \frac {\rho \cdot  g \cdot h^3 \cdot l_p}{6 \cdot b_p} -\rho \cdot g \cdot h \cdot l_p \cdot \frac{b_p}{2}=0\\
# $$
#
# Simplifying the equation and calculating h
#
# $$
# h= \sqrt {3 \cdot b_p^2}\\
# $$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h=(3*b_p**2)**0.5 #m
# Out:
# \[
# \begin{aligned}
# h &= 2.60 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# ## Problems for Lecture 8: Forces on curved surfaces

# %% [markdown]
# ### Force on a spherical container

# %% [markdown]
# ---
# #### Question 1 (**) [R]

# %% [markdown]
# A spherical steel tank of 15 m diameter contains gas under a pressure of 350 kPa. The tank consists of two half-spheres joined together with a weld. What is the total force on the weld? What will the tensile force across the weld be in kN/m? {61.8 MN; 1.31 MN/m}

# %% [markdown]
# **Given:**

# %%
# %%render param
# d=15 #m
# p=350*1000 #Pa
# Out:
# \[
# \begin{aligned}
# d &= 15 \; \;\textrm{(m)}
#  &p &= 350000 \; \;\textrm{(Pa)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The force on the weld can be calculated as:
#
# $$F=p A$$
#
# Where $p$ is given and $A=\pi r^2$
#
# The tensile force across the weld is equal to:
#
# $$
# F_{tensile}= \frac{F}{perimeter}
# $$
#
# Where
#
# $$
# perimeter=\pi d
# $$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# A= pi*d**2/4 #m2
# F_weld= p*A #N
#
# perimeter= pi*d #m
# F_tensile= F_weld/perimeter #N/m
# Out:
# \[
# \begin{aligned}
# A &= \pi \cdot \frac{ \left( d \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 15 \right) ^{ 2 } }{ 4 } \\&= 176.715 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F_{weld} &= p \cdot A \\&= 350000 \cdot 176.715 \\&= 61850105.368 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# \mathrm{perimeter} &= \pi \cdot d \\&= 3.142 \cdot 15 \\&= 47.124 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# F_{tensile} &= \frac{ F_{weld} }{ \mathrm{perimeter} } \\&= \frac{ 61850105.368 }{ 47.124 } \\&= 1312500.000 \; \;\textrm{(N/m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2 (***)

# %% [markdown]
# By how much does the pressure inside a 2 mm diameter spherical water droplet exceed the pressure in the surrounding air? Work from basic principles and assume the water/air surface tension to be 0.0735 N/m.  {147 Pa}

# %% [markdown]
# **Given:**

# %%
# %%render param
# d= 2#mm
# sigma= 0.0735 #N/m
# Out:
# \[
# \begin{aligned}
# d &= 2 \; \;\textrm{(mm)}
#  &\sigma &= 0.073 \; \;\textrm{(N/m)}
# \end{aligned}
# \]

# %%
from PIL import Image
img = Image.open(r"figures/65.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=193x204 at 0x1D0C37C7E80>

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# To calculate the pressure diference in a spherical water droplet, it must be assumed that the droplet is in equilibrium, meaning the sum of forces is equal to 0. Additionally, considering the forces found in the image, the following equations are obtained.
#
# $$
# \sum F =0 \\
# F_{\sigma}-F_p=0\\
# $$
#
# $F_{\sigma}$ is the force of the surface tension
#
# $$
# F_{\sigma}= \sigma l_{circum}\\
# F_{\sigma}= \sigma \pi d
# $$
#
# An the $F_p$ is the pressure force
#
# $$
# F_p= \Delta p A\\
# F_p=\Delta p \frac {\pi d^2}{4}
# $$
#
# Replacing the two forces in the sum of forces we have:
#
# $$
# \sigma \pi d=\Delta p \frac {\pi d^2}{4}\\
# \Delta p =\frac {4\sigma}{d}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# Delta_P= 4*sigma/(d/1000) #Pa
# Out:
# \[
# \begin{aligned}
# \Delta_{P} &= 4 \cdot \frac{ \sigma }{ \frac{ d }{ 1000 } } \\&= 4 \cdot \frac{ 0.073 }{ \frac{ 2 }{ 1000 } } \\&= 147.000 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 3 (***)

# %% [markdown]
# By how much does the pressure inside a 2 mm diameter air bubble in 15 °C water exceed the pressure in the surrounding water?  {147 Pa}

# %% [markdown]
# **Given:**

# %%
# %%render param
# d=2/1000 #m
# T=15 #°C
# Out:
# \[
# \begin{aligned}
# d &= 0.002 \; \;\textrm{(m)}
#  &T &= 15 \; \;\textrm{(°C)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# In Table A.1 the surface tension of water at 15°C is: 0.073 N/m
#
# Cutting the bubble on a plane through its center and considering force equilibrium:
#
# $$
# \sum F_x =0 \\
# F_{\sigma}-F_p=0\\
# F_{\sigma}= \sigma \pi d \\
# F_P=\Delta p \frac {\pi d^2}{4}
# $$
#
# Replacing the two forces in the sum of forces we have:
#
# $$
# \sigma \pi d=\Delta p \frac {\pi d^2}{4}\\
# \Delta p =\frac {4\sigma}{d}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# sigma= 0.0735 #N/m
# dP= 4*sigma/d #Pa
# Out:
# \[
# \begin{aligned}
# \sigma &= 0.073 \; \;\textrm{(N/m)}
# \\[10pt]
# \mathrm{dP} &= 4 \cdot \frac{ \sigma }{ d } \\&= 4 \cdot \frac{ 0.073 }{ 0.002 } \\&= 147.000 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 4 (***)[R]

# %% [markdown]
# Calculate the gauge pressure inside a 50 mm diameter soap bubble from basic principles. Assume a temperature of 15°C and that the soap does not significantly change the properties of the water. (Tip: note that a soap bubble will have air-fluid surfaces at both its inner and outer diameters) {11.8 Pa}

# %% [markdown]
# **Given:**

# %%
# %%render param
# d=50 #mm
# Out:
# \[
# \begin{aligned}
# d &= 50 \; \;\textrm{(mm)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
#
# In Table A.1 the surface tension of water at 15°C is $\sigma= 0.0735 N/m$
#
# To calculate the pressure diference in a spherical water droplet, it must be assumed that the droplet is in equilibrium, meaning the sum of forces is equal to 0. Additionally, considering the forces found in the image, the following equations are obtained.
#
# $$
# \sum F =0 \\
# 2 \cdot F_{\sigma}-F_P=0\\
# $$
#
# $F_{\sigma}$ is the force of the surface tension
#
# $$
# F_{\sigma}= 2 \cdot \sigma l_{circum}\\
# F_{\sigma}= 2 \cdot \sigma \pi d
# $$
#
# An the $F_p$ is the pressure force
#
# $$
# F_p= \Delta p A\\
# F_p=\Delta p \frac {\pi d^2}{4}
# $$
#
# Replacing the two forces in the sum of forces we have:
#
# $$
# 2\sigma \pi d=\Delta P \frac {\pi d^2}{4}\\
# \Delta P =\frac {8\sigma}{d}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# sigma= 0.0735 #N/m
# Delta_P= 8*sigma/(d/1000) #Pa
# Out:
# \[
# \begin{aligned}
# \sigma &= 0.073 \; \;\textrm{(N/m)}
# \\[10pt]
# \Delta_{P} &= 8 \cdot \frac{ \sigma }{ \frac{ d }{ 1000 } } \\&= 8 \cdot \frac{ 0.073 }{ \frac{ 50 }{ 1000 } } \\&= 11.760 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 5 (***)

# %% [markdown]
# The cylindrical tank below has a hemispherical end cap ABC. Calculate the total horizontal force exerted on ABC by the oil and water. {560 kN}

# %%
img = Image.open(r"figures/68.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=363x269 at 0x276B9000880>

# %% [markdown]
# **Given:**

# %%
# %%render param
# L_AB= 2 #m
# L_BC= 2 #m
# s_oil= 0.9
# h= 3 #m
# Out:
# \[
# \begin{aligned}
# L_{AB} &= 2 \; \;\textrm{(m)}
#  &L_{BC} &= 2 \; \;\textrm{(m)}
#  &s_{oil} &= 0.900 \;
# \\[10pt]
#  h &= 3 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The force in AB is:
#
# $$
# F_{AB}=\rho g h_c A
# $$
#
# Where $h_c$ is:
#
# $$
# h_c=3+2-centroid\\
# centroid= \frac{4r}{3\pi}
# $$
#
#
# The force in BC is:
#
# $$
# F_{BC}=\rho_{oil} g h A + \rho_{water} g h_c A
# $$
#
# Where $h_c$ is:
#
# $$
# h_c=centroid\\
# centroid= \frac{4r}{3\pi}
# $$
#
# Finally the force ABC is:
#
# $$
# F_{ABC} = F_{AB} + F_{BC}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# rho_oil= s_oil*rho_water #kg/m3
# r= 2#m
# h_c= h+r-(4*r)/(3*pi) #m
# A= (pi*r**2)/2 #m2
# F_AB= rho_oil*g*h_c*A #N
#
# F_BC= rho_oil*g*(h+r)*A+rho_water*g*(4*r)/(3*pi)*A #N
#
# F_ABC= F_AB+F_BC #N
# Out:
# \[
# \begin{aligned}
# \rho_{oil} &= s_{oil} \cdot \rho_{water} \\&= 0.900 \cdot 1000 \\&= 900.000 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# r &= 2 \; \;\textrm{(m)}
# \\[10pt]
# h_{c} &= h + r - \frac{ 4 \cdot r }{ 3 \cdot \pi } \\&= 3 + 2 - \frac{ 4 \cdot 2 }{ 3 \cdot 3.142 } \\&= 4.151 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= \frac{ \pi \cdot \left( r \right) ^{ 2 } }{ 2 } \\&= \frac{ 3.142 \cdot \left( 2 \right) ^{ 2 } }{ 2 } \\&= 6.283 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F_{AB} &= \rho_{oil} \cdot g \cdot h_{c} \cdot A \\&= 900.000 \cdot 9.810 \cdot 4.151 \cdot 6.283 \\&= 230283.215 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# F_{BC} &= \rho_{oil} \cdot g \cdot \left( h + r \right) \cdot A + \rho_{water} \cdot g \cdot \frac{ 4 \cdot r }{ 3 \cdot \pi } \cdot A \\&= 900.000 \cdot 9.810 \cdot \left( 3 + 2 \right) \cdot 6.283 + 1000 \cdot 9.810 \cdot \frac{ 4 \cdot 2 }{ 3 \cdot 3.142 } \cdot 6.283 \\&= 329691.215 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# F_{ABC} &= F_{AB} + F_{BC} \\&= 230283.215 + 329691.215 \\&= 559974.431 \; \;\textrm{(N)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 6 (** - ***)[R]

# %% [markdown]
# The rectangular tank shown below has a width of 3 m into the page and a maximum water depth of 6 m. One of the bottom edges of the tank consists of a curved panel with a radius of 1 m.
#
#    a.**Calculate the size and line of action of the horizontal hydrostatic force on the curved panel. {161.9 kN acting 5.515 m from the water surface}
#
#    b.**Calculate the size of the vertical hydrostatic force on the curved panel. {170.3 kN}
#
#    c.***Calculate the line of action of the vertical hydrostatic force on the curved panel. {0.510 m from right tank edge}
#
#    d.**Calculate the size and line of action of the resultant hydrostatic force exerted on the curved panel. {234.93 kN acting at 43.55 ° from the vertical}
#
#    e.***Show that the resultant hydrostatic force acts perpendicularly on the curved panel.

# %% [markdown]
# **Given:**

# %%
from PIL import Image
img = Image.open(r"figures/69.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=251x253 at 0x1D0C22F45E0>

# %%
# %%render param
# B=3 #m
# h=6#m
# r=1#m
# Out:
# \[
# \begin{aligned}
# B &= 3 \; \;\textrm{(m)}
#  &h &= 6 \; \;\textrm{(m)}
#  &r &= 1 \; \;\textrm{(m)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# To calculate the magnitud of the horizontal hydrostatic force the following equations should be used:
#
# $$
# F_x= \rho g h_c A\\
# y_p=y_c + \frac {I_c}{y_cA}
# $$
#
# In this case $y_c$ and $h_c$ are the same as there is no inclination.
#
# The horizontal force is calcualted in the vertical projection of the tank. Considering the projection is a rectangular shape, the following equations can be used:
#
# $$
# h_c= h_{above curve panel} + \frac {r_{projection}}{2}\\
# $$
#
# $$
# A= br_{projection}\\
# $$
#
# $$
# I_c= \frac {br^3}{12}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h_c= (h-r)+r/2 #m
# A = B*r
# F_x= rho_water*g*h_c*A/1000 #kN
# I_c= B*r**3/12 #m4
# y_p= h_c+I_c/(h_c*A)#m
# Out:
# \[
# \begin{aligned}
# h_{c} &= \left( h - r \right) + \frac{ r }{ 2 } \\&= \left( 6 - 1 \right) + \frac{ 1 }{ 2 } \\&= 5.50 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= B \cdot r \\&= 3 \cdot 1 \\&= 3  \\[10pt]
# \\[10pt]
# F_{x} &= \rho_{water} \cdot g \cdot h_{c} \cdot \frac{ A }{ 1000 } \\&= 1000 \cdot 9.81 \cdot 5.50 \cdot \frac{ 3 }{ 1000 } \\&= 161.87 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# I_{c} &= B \cdot \frac{ \left( r \right) ^{ 3 } }{ 12 } \\&= 3 \cdot \frac{ \left( 1 \right) ^{ 3 } }{ 12 } \\&= 0.25 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p} &= h_{c} + \frac{ I_{c} }{ h_{c} \cdot A } \\&= 5.50 + \frac{ 0.25 }{ 5.50 \cdot 3 } \\&= 5.52 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The vertical force acting on any area is equal to the weight of the volume of liquid above it,for that reason, the following equations can be used.
#
# $F_y$ = Weight of fluid above the panel
#
# $$
# F_y = \rho g V
# $$
#
# The volume for this exercise is the addition between the volume of the rectangule of height 5 m and the volume of a quarter of a circle
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# V= pi*r**2*B/4+B*(h-r)*r #m3
# F_y= rho_water*g*V/1000  #kN
# Out:
# \[
# \begin{aligned}
# V &= \pi \cdot \left( r \right) ^{ 2 } \cdot \frac{ B }{ 4 } + B \cdot \left( h - r \right) \cdot r \\&= 3.1 \cdot \left( 1 \right) ^{ 2 } \cdot \frac{ 3 }{ 4 } + 3 \cdot \left( 6 - 1 \right) \cdot 1 \\&= 17.4 \; \;\textrm{(m3)}\\[10pt]
# \\[10pt]
# F_{y} &= \rho_{water} \cdot g \cdot \frac{ V }{ 1000 } \\&= 1000 \cdot 9.8 \cdot \frac{ 17.4 }{ 1000 } \\&= 170.3 \; \;\textrm{(kN)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# c)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# To calculate the line of action of the vertical force, the centroid of the figure must be calculated, which in this exercise is composed of a rectangle and a quarter of a circle.
#
# The centroid of complex figure can be calculated using the following equation:
#
# $$
# \bar X = \frac {\sum \bar XA}{\sum A}
# $$
#
# The centroid of a quarter of circle is
#
# $$
# X= \frac {4r}{3\pi}\\
# $$
#
# The centroid of a rectangle is
#
# $$
# X= \frac {h}{2}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# A_circ= pi*r**2/4 #m2
# A_rect= (h-r)*r #m2
# X_circ= 4*r/(3*pi)#m
# X_rect= r/2 #m
# A_total= A_circ+ A_rect #m2
# X= (X_rect*A_rect+X_circ*A_circ)/A_total #m
# Out:
# \[
# \begin{aligned}
# A_{circ} &= \pi \cdot \frac{ \left( r \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 1 \right) ^{ 2 } }{ 4 } \\&= 0.79 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# A_{rect} &= \left( h - r \right) \cdot r \\&= \left( 6 - 1 \right) \cdot 1 \\&= 5 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# X_{circ} &= 4 \cdot \frac{ r }{ 3 \cdot \pi } \\&= 4 \cdot \frac{ 1 }{ 3 \cdot 3.14 } \\&= 0.42 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# X_{rect} &= \frac{ r }{ 2 } \\&= \frac{ 1 }{ 2 } \\&= 0.50 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A_{total} &= A_{circ} + A_{rect} \\&= 0.79 + 5 \\&= 5.79 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# X &= \frac{ X_{rect} \cdot A_{rect} + X_{circ} \cdot A_{circ} }{ A_{total} } \\&= \frac{ 0.50 \cdot 5 + 0.42 \cdot 0.79 }{ 5.79 } \\&= 0.49 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# d)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The size and line of action of the resultant force can be calculated as:
#
# $$
# F_r=\sqrt{F_x^2+F_y^2}\\
# tan (\theta) = \frac {F_x}{F_y}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# F_r= sqrt(F_x**2+F_y**2) #kN
# theta=degrees(atan(F_x/F_y)) #°
# Out:
# \[
# \begin{aligned}
# F_{r} &= \sqrt { \left( F_{x} \right) ^{ 2 } + \left( F_{y} \right) ^{ 2 } } \\&= \sqrt { \left( 161.87 \right) ^{ 2 } + \left( 170.26 \right) ^{ 2 } } \\&= 234.93 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# \theta &= 43.55 \; \;\textrm{(°)}
# \end{aligned}
# \]

# %% [markdown]
# e)

# %% [markdown]
# **Hint**

# %%
from PIL import Image
img = Image.open(r"figures/69S.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=241x178 at 0x21F15DD7400>

# %% [markdown]
# ```{toggle}
# To show that the resultant hydrostatic force acts perpendicularly on the curved panel is necessary to calculate the angle between O and A (in the figure above).
#
# This angle can be calculated with the following equation
#
# $$
# tan (\theta_ = \frac {X_O}{Y_O}
# $$
#
# Where $X_O$ is the distance between O and the force, meaning the centroid of the vertical force calculated in point c). $Y_O$ is the distance between O and the force, meaning the distance from the surface to where the force is applied, minus the distance from the surface to O (5m).
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# X_O= X #m
# Y_O= y_p-h+r#m
# theta= degrees(atan(X_O/Y_O)) #°
# Out:
# \[
# \begin{aligned}
# X_{O} &= 0.49 \; \;\textrm{(m)}
# \\[10pt]
# Y_{O} &= y_{p} - h + r \\&= 5.52 - 6 + 1 \\&= 0.52 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# \theta &= \operatorname{degrees} { \left( \arctan \left( \frac{ X_{O} }{ Y_{O} } \right) \right) } \\&= \operatorname{degrees} { \left( \arctan \left( \frac{ 0.49 }{ 0.52 } \right) \right) } \\&= 43.55 \; \;\textrm{(°)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Circumferential stresses in cylindrical container

# %% [markdown]
# ---
# #### Question 7 (***)

# %% [markdown]
# Two identical rigid cylinders with one end open are used in an experiment. Each cylinder has an internal diameter of 20 mm and an internal length of 10 m. The cylinders are placed upright with their open ends at the top under standard sea level conditions as shown in the diagram. Cylinder A is left empty, while cylinder B is completely filled with water. A perfectly sealing frictionless piston is then inserted into each cylinder and loaded with weights to a total mass (including the piston) of 200 kg. Assume the specific constant of air Rs = 287 J/kgK. Determine the following for each cylinder:
#
# a) The internal pressure at the top of the cylinder (just below the piston). {6.245 MPa}
# b) The equilibrium height of the piston above the floor. Assume that the temperature of the water and gas do not change due to the compression. {160 mm; 9.971 m}
# c) The circumferential stress in the air cylinder wall. Assume a cylinder wall thickness of 20 mm and work from basic principles. {3.123 MPa}

# %%
img = Image.open(r"figures/70.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=827x590 at 0x21F15BB1580>

# %% [markdown]
# **Given:**

# %%
# %%render param
# d= 20/1000 #m
# L= 10 #m
# m= 200 #kg
# R_s= 287 #J/kgK
# Out:
# \[
# \begin{aligned}
# d &= 0.020 \; \;\textrm{(m)}
#  &L &= 10 \; \;\textrm{(m)}
#  &m &= 200 \; \;\textrm{(kg)}
# \\[10pt]
#  R_{s} &= 287 \; \;\textrm{(J/kgK)}
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The internal pressure at the top of the cylinder is calculated the same way in cylinder A and B. It is calculated as follows:
#
# $$
# \sum F_y=0\\
# $$
#
# $$
# W -F_p=0\\
# $$
#
# $$
# W= pA
# $$
#
# $$
# p=W/A
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# W= m*g #N
# A= pi*(d/2)**2 #m2
# p= W/A #Pa
# Out:
# \[
# \begin{aligned}
# W &= m \cdot g \\&= 200 \cdot 9.8100 \\&= 1962.0000 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \left( \frac{ d }{ 2 } \right) ^{ 2 } \\&= 3.1416 \cdot \left( \frac{ 0.0200 }{ 2 } \right) ^{ 2 } \\&= 0.0003 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# p &= \frac{ W }{ A } \\&= \frac{ 1962.0000 }{ 0.0003 } \\&= 6245239.9669 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# **Cylinder A:**
#
# $$
# \frac{p}{\rho}=R_s T
# $$
#
# Assuming no change in T:
#
# $$
# \frac{p_1}{\rho_1}=\frac{p_2}{\rho_2}\\
# \rho_2=p_2 \frac{\rho_1}{p_1}
# $$
#
# From Table A.3: $\rho_1=1.225 kg/m^3$ and $p_1=101325 Pa$
#
# From conservation of mass:
#
# $$
# \rho_1 Vol_1 =\rho_2 Vol_2\\
# \rho_1 \cdot A \cdot L_1 =\rho_2 \cdot A \cdot L_2
# $$
#
# Solving for $L_2$:
#
# $$
# L_2=  \frac{\rho_1 L_1}{\rho_2}
# $$
#
#
#
#
#
# **Cylinder B:**
#
# Considering:
#
# $$
# -\Delta p= E_v \frac{\Delta v}{v}\\
# v= 1/\rho_{water}
# $$
#
# and, from Table A.1 at 15°C, $E_v= 2.14*10^9 Pa$
#
# $\Delta v$ can be solved.
# Then, considering that:
#
# $$
# v_2=v+\Delta v\\
# \rho_2=\frac{1}{v_2}
# $$
#
# and from conservation of mass:
#
# $$
# \rho_1 \cdot Vol_1 =\rho_2 \cdot Vol_2\\
# \rho_1 \cdot A \cdot L_1 =\rho_2 \cdot AL2
# $$
#
# $L_2$ can be calculated as:
#
# $$
# L_2=  \frac{\rho_1 L_1}{\rho_2}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# rho_1A=1.225 #kg/m3
# p_1A=101325 #Pa
#
# p_2A= p_1A+p #Pa
# rho_2A= p_2A*rho_1A/p_1A #kg/m3
#
# L_1= L #m
# L_2A= rho_1A*L_1/rho_2A #m
#
# E_vB=2.14*10**9 #Pa
#
# v_B= 1/rho_water #m3/kg
#
# dv_B= -p/E_vB*v_B #m3
# v_2B=v_B +dv_B #m3
#
# rho_2B= 1/v_2B #kg/m3
#
# L_2B= rho_water*L_1/rho_2B #m
# Out:
# \[
# \begin{aligned}
# \rho_{1A} &= 1.225 \; \;\textrm{(kg/m3)}
# \\[10pt]
# p_{1A} &= 101325 \; \;\textrm{(Pa)}
# \\[10pt]
# p_{2A} &= p_{1A} + p \\&= 101325 + 6245239.967 \\&= 6346564.967 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# \rho_{2A} &= p_{2A} \cdot \frac{ \rho_{1A} }{ p_{1A} } \\&= 6346564.967 \cdot \frac{ 1.225 }{ 101325 } \\&= 76.729 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# L_{1} &= 10 \; \;\textrm{(m)}
# \\[10pt]
# L_{2A} &= \rho_{1A} \cdot \frac{ L_{1} }{ \rho_{2A} } \\&= 1.225 \cdot \frac{ 10 }{ 76.729 } \\&= 0.160 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# E_{vB} &= 2140000000.000 \; \;\textrm{(Pa)}
# \\[10pt]
# v_{B} &= \frac{ 1 }{ \rho_{water} } \\&= \frac{ 1 }{ 1000 } \\&= 0.001 \; \;\textrm{(m3/kg)}\\[10pt]
# \\[10pt]
# \mathrm{dv}_{B} &= \frac{ \left( - p \right) }{ E_{vB} } \cdot v_{B} \\&= \frac{ \left( - 6245239.967 \right) }{ 2140000000.000 } \cdot 0.001 \\&= -0.000 \; \;\textrm{(m3)}\\[10pt]
# \\[10pt]
# v_{2B} &= v_{B} + \mathrm{dv}_{B} \\&= 0.001 + -0.000 \\&= 0.001 \; \;\textrm{(m3)}\\[10pt]
# \\[10pt]
# \rho_{2B} &= \frac{ 1 }{ v_{2B} } \\&= \frac{ 1 }{ 0.001 } \\&= 1002.927 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# L_{2B} &= \rho_{water} \cdot \frac{ L_{1} }{ \rho_{2B} } \\&= 1000 \cdot \frac{ 10 }{ 1002.927 } \\&= 9.971 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# c)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The circumferential stress in the air cylinder wall can be calculated with the following equation:
#
# $$
# \sum F_x=0\\
# $$
#
# $$
# F_p_x- F_{sigma}=0
# $$
#
# $$
# pdL=2 \sigma Lt
# $$
#
# Solving for $\sigma$:
#
# $$\sigma= \frac{Pd}{2t}$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# t=20/1000 #m
# sigma= p*d/(2*t)/1000000 #MPa
# Out:
# \[
# \begin{aligned}
# t &= 0.02 \; \;\textrm{(m)}
# \\[10pt]
# \sigma &= p \cdot \frac{ d }{ 2 \cdot t } \cdot \frac{1} { 1000000 } \\&= 6245239.97 \cdot \frac{ 0.02 }{ 2 \cdot 0.02 } \cdot \frac{1} { 1000000 } \\&= 3.12 \; \;\textrm{(MPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ## Problems for Lecture 9: Buoyancy

# %% [markdown]
# ### Basic buoyancy problems

# %% [markdown]
# ---
# #### Question 1 (*)[R]

# %% [markdown]
# What is the weight of the loaded barge below? The barge is 7 m in width. {2 703 kN}

# %%
img = Image.open(r"figures/71.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=494x273 at 0x1D0C36DAA60>

# %% [markdown]
# **Given:**

# %%
# %%render param
# h= 2.4 #m
# l= 14 #m
# B= 7 #m
# theta= 45 #°
# Out:
# \[
# \begin{aligned}
# h &= 2.400 \; \;\textrm{(m)}
#  &l &= 14 \; \;\textrm{(m)}
#  &B &= 7 \; \;\textrm{(m)}
# \\[10pt]
#  \theta &= 45 \; \;\textrm{(°)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# By doing the sum of force in the y axis, the weight of the loaded barge can be calculated
#
# $$
# \sum F_y=0\\
# F_b-W=0\\
# $$
#
# $$
# F_b=W\\
# \rho \cdot  g \cdot  Vol = W
# $$
#
# Where the volume is the sum of the rectangle plus the two lateral triangles.
#
# $$
# Vol= b_{rec} \cdot h_{rec} \cdot  B + \frac {b_{tri} \cdot  h_{tri}}{2}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 0
# theta_ra=radians(theta)
# Vol= (h*l*B)+2*(((h*h*tan(theta_ra))/2)*B) #m3
# W= rho_water*g*Vol/1000 #kN
# Out:
# \[
# \begin{aligned}
# \theta_{ra} &= 1 \;
# \\[10pt]
# \mathrm{Vol} &= \left( h \cdot l \cdot B \right) + 2 \cdot \left( \left( \frac{ h \cdot h \cdot \tan \left( \theta_{ra} \right) }{ 2 } \right) \cdot B \right) \\&= \left( 2 \cdot 14 \cdot 7 \right) + 2 \cdot \left( \left( \frac{ 2 \cdot 2 \cdot \tan \left( 1 \right) }{ 2 } \right) \cdot 7 \right) \\&= 276 \; \;\textrm{(m3)}\\[10pt]
# \\[10pt]
# W &= \rho_{water} \cdot g \cdot \frac{ \mathrm{Vol} }{ 1000 } \\&= 1000 \cdot 10 \cdot \frac{ 276 }{ 1000 } \\&= 2703 \; \;\textrm{(kN)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2 (**)[R]

# %% [markdown]
# Determine the magnitude and direction of the force necessary to hold a concrete cube 300 mm on each side completely submerged in a) mercury, and b) water. Assume the density of concrete and mercury as 2 400 kg/m<sup>3</sup> and 13 600 kg/m<sup>3</sup> respectively. {2.97 kN downward, 371 N upward}

# %% [markdown]
# **Given:**

# %%
# %%render param
# L= 300 #mm
# rho_concrete=2400 #kg/m3
# rho_Hg=13600 #kg/m3
# Out:
# \[
# \begin{aligned}
# L &= 300 \; \;\textrm{(mm)}
#  &\rho_{concrete} &= 2400 \; \;\textrm{(kg/m3)}
#  &\rho_{Hg} &= 13600 \; \;\textrm{(kg/m3)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# By doing the sum of force we can solve the force necessary to hold the cube:
#
# $$
# \sum F =0 \\
# $$
#
# $$
# F+W-F_b=0\\
# $$
#
# $$
# F=F_b-W
# $$
#
# Where the weight is $W = \rho_{\text{concrete}} \cdot g \cdot \left( \frac{L}{1000} \right)^3$ and the bouyant force is $F_b = \rho_{\text{Hg}} \cdot g \cdot \left( \frac{L}{1000} \right)^3$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# W= rho_concrete*g*(L/1000)**3 #N
# F_b= rho_Hg*g*(L/1000)**3 #N
# F= F_b-W #N
# Out:
# \[
# \begin{aligned}
# W &= \rho_{concrete} \cdot g \cdot \left( \frac{ L }{ 1000 } \right) ^{ 3 } \\&= 2400 \cdot 9.81 \cdot \left( \frac{ 300 }{ 1000 } \right) ^{ 3 } \\&= 635.69 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# F_{b} &= \rho_{Hg} \cdot g \cdot \left( \frac{ L }{ 1000 } \right) ^{ 3 } \\&= 13600 \cdot 9.81 \cdot \left( \frac{ 300 }{ 1000 } \right) ^{ 3 } \\&= 3602.23 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# F &= F_{b} - W \\&= 3602.23 - 635.69 \\&= 2966.54 \; \;\textrm{(N)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The cube will sink in water, for this reason, a force F acting upward will be required to hold the concrete in equilibirum and completely sumerged in water.
#
# $$
# \sum F =0 \\
# W-F-F_b=0\\
# F=W-F_b
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# W= rho_concrete*g*(L/1000)**3 #N
# F_b= rho_water*g*(L/1000)**3 #N
# F= W-F_b #N
# Out:
# \[
# \begin{aligned}
# W &= \rho_{concrete} \cdot g \cdot \left( \frac{ L }{ 1000 } \right) ^{ 3 } \\&= 2400 \cdot 9.81 \cdot \left( \frac{ 300 }{ 1000 } \right) ^{ 3 } \\&= 635.69 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# F_{b} &= \rho_{water} \cdot g \cdot \left( \frac{ L }{ 1000 } \right) ^{ 3 } \\&= 1000 \cdot 9.81 \cdot \left( \frac{ 300 }{ 1000 } \right) ^{ 3 } \\&= 264.87 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# F &= W - F_{b} \\&= 635.69 - 264.87 \\&= 370.82 \; \;\textrm{(N)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 3 (**)

# %% [markdown]
# A cylinder with diameter 8 cm and height 11 cm floats upright in water with 4 cm sticking out above the water. Determine the weight of the cylinder. {3.45 N}

# %% [markdown]
# **Given:**

# %%
# %%render param
# d= 8/100 #m
# l= 11/100 #m
# h_out= 4/100 #m
# Out:
# \[
# \begin{aligned}
# d &= 0.080 \; \;\textrm{(m)}
#  &l &= 0.110 \; \;\textrm{(m)}
#  &h_{out} &= 0.040 \; \;\textrm{(m)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# By doing the sum of force in the y axis, the weight of the cylinder can be calculated
#
# $$
# \sum F_y=0\\
# F_b-W=0\\
# $$
#
# $$
# F_b=W\\
# W=\rho g Vol_{displayed}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# A= pi*d**2/4 #m2
# h_in= l-h_out #m
# Vol_displayed= A*h_in #m3
# W= rho_water*g*Vol_displayed #N
# Out:
# \[
# \begin{aligned}
# A &= \pi \cdot \frac{ \left( d \right) ^{ 2 } }{ 4 } \\&= 3.1416 \cdot \frac{ \left( 0.0800 \right) ^{ 2 } }{ 4 } \\&= 0.0050 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# h_{in} &= l - h_{out} \\&= 0.1100 - 0.0400 \\&= 0.0700 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# \mathrm{Vol}_{displayed} &= A \cdot h_{in} \\&= 0.0050 \cdot 0.0700 \\&= 0.0004 \; \;\textrm{(m3)}\\[10pt]
# \\[10pt]
# W &= \rho_{water} \cdot g \cdot \mathrm{Vol}_{displayed} \\&= 1000 \cdot 9.8100 \cdot 0.0004 \\&= 3.4517 \; \;\textrm{(N)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 4 (**)

# %% [markdown]
# An irregularly shaped metal weighs 300.0 N in air. When it is completely submerged in water, it weighs 232.5 N. Find the volume of the metal. {0.00688 m3}

# %% [markdown]
# **Given:**

# %%
# %%render param
# W_air= 300 #N
# W_water= 232.5 #N
# Out:
# \[
# \begin{aligned}
# W_{air} &= 300 \; \;\textrm{(N)}
#  &W_{water} &= 232.500 \; \;\textrm{(N)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# When the object is submerged in the water the sum of forces is:
#
# $$W_{air}-W_{water}=F_b$$
#
# Replacing the bouyant force we have:
#
# $$W_{air}-W_{water}= \rho_{water}gV$$
#
# Solving the volume:
#
# $$V= \frac{W_{air}-W_{water}}{\rho_{water}g}$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# Vol= (W_air-W_water)/(g*rho_water) #m3
# Out:
# \[
# \begin{aligned}
# \mathrm{Vol} &= \frac{ W_{air} - W_{water} }{ g \cdot \rho_{water} } \\&= \frac{ 300 - 232.500 }{ 9.810 \cdot 1000 } \\&= 0.007 \; \;\textrm{(m3)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Floating bodies

# %% [markdown]
# ---
# #### Question 5 (**)

# %% [markdown]
# A hollow cube, 1 m on each side, weighs 2.4 kN. The cube is tied to a solid concrete block weighing 10 kN. Will these two objects tied together float or sink in water? The specific gravity of concrete is 2.4. {if fully submerged Fbuoyancy = 14 kN; W = 12.4 kN; thus body will float}

# %% [markdown]
# **Given:**

# %%
# %%render param 1
# L= 1 #m
# W_hollow= 2.4*1000 #N
# W_solid= 10*1000 #N
# s= 2.4
# Out:
# \[
# \begin{aligned}
# L &= 1 \; \;\textrm{(m)}
#  &W_{hollow} &= 2400.0 \; \;\textrm{(N)}
#  &W_{solid} &= 10000 \; \;\textrm{(N)}
# \\[10pt]
#  s &= 2.4 \;
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The object will float if the buoyant force is greater than its weight. For that reason, the total weight of the object and the buoyant force should be calculated using the following equations.
#
# $$
# W_{total}= W_{hollow}+ W_{solid}\\
# $$
#
# $$
# Fb_{total}= Fb_{hollow}+ Fb_{solid}\\
# $$
#
# $$
# Fb_{total}= \rho g V_{hollow}+ \rho g V_{solid}\\
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# W_total= W_hollow+W_solid #N
#
# Vol_hollow= L**3 #m3
# F_b_hollow= rho_water*g*Vol_hollow #N
#
# rho_solid= s*rho_water #kg/m3
# m_solid= W_solid/g #kg
# Vol_solid= m_solid/rho_solid #m3
# F_b_solid= rho_water*g*Vol_solid #N
#
# F_b= F_b_hollow+F_b_solid #N
# Out:
# \[
# \begin{aligned}
# W_{total} &= W_{hollow} + W_{solid} \\&= 2400.000 + 10000 \\&= 12400.000 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# \mathrm{Vol}_{hollow} &= \left( L \right) ^{ 3 } \\&= \left( 1 \right) ^{ 3 } \\&= 1 \; \;\textrm{(m3)}\\[10pt]
# \\[10pt]
# F_{b_{hollow}} &= \rho_{water} \cdot g \cdot \mathrm{Vol}_{hollow} \\&= 1000 \cdot 9.810 \cdot 1 \\&= 9810.000 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# \rho_{solid} &= s \cdot \rho_{water} \\&= 2.400 \cdot 1000 \\&= 2400.000 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# m_{solid} &= \frac{ W_{solid} }{ g } \\&= \frac{ 10000 }{ 9.810 } \\&= 1019.368 \; \;\textrm{(kg)}\\[10pt]
# \\[10pt]
# \mathrm{Vol}_{solid} &= \frac{ m_{solid} }{ \rho_{solid} } \\&= \frac{ 1019.368 }{ 2400.000 } \\&= 0.425 \; \;\textrm{(m3)}\\[10pt]
# \\[10pt]
# F_{b_{solid}} &= \rho_{water} \cdot g \cdot \mathrm{Vol}_{solid} \\&= 1000 \cdot 9.810 \cdot 0.425 \\&= 4166.667 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# F_{b} &= F_{b_{hollow}} + F_{b_{solid}} \\&= 9810.000 + 4166.667 \\&= 13976.667 \; \;\textrm{(N)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# $$
# F_b>W_{total}\\
# $$
#
# The two block tied together will float

# %% [markdown]
# ---
# #### Question 6(**)[R]

# %% [markdown]
# A block of steel (s = 7.85) will float at a mercury-water interface as shown below. What will the ratio of distances a to b be for this condition? {0.839}

# %%
from PIL import Image
img = Image.open(r"figures/76.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=405x257 at 0x276B8862A90>

# %% [markdown]
# **Given:**

# %%
# %%render param
# s=7.85
# Out:
# \[
# \begin{aligned}
# s &= 7.850 \;
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# Let width of block= c and length of block= d, from the summation of forces, the ratio of distances a to b can be solved as follows:
#
#
# $$
# \sum F_y =0
# $$
#
# $$
# F_b = W\\
# $$
#
# Where the $F_b$ is the total buoyant force from the volume submerged in mercury and the volume submerged in water:
#
# $$
# F_b = c \cdot  d \cdot  a \cdot  \rho_{water}+c \cdot  d \cdot  b \cdot  \rho_{Hg}\\
# $$
#
# and the $W$ is:
#
# $$
# W= c \cdot  d \cdot  (a+b)\rho_{steel}\\
# $$
#
# Replacing both equation in the sum of forces we have:
#
# $$
# c \cdot  d \cdot  a \cdot \rho_{water}+ c \cdot  d \cdot  b \cdot \rho_{Hg}= c \cdot  d \cdot (a+b) \cdot \rho_{steel}\\
# $$
#
# replacing the densities of the liquids we have:
#
# $$
# c \cdot  d \cdot  a \cdot 1000 + c \cdot  d \cdot  b \cdot 13600=c \cdot  d \cdot (a+b)7850\\
# $$
#
#
# $$
# a \cdot 1000+b \cdot 13600=(a+b) \cdot 7850\\
# $$
#
# $$
# 1000 \cdot a-7850 \cdot a =7850 \cdot b-13600 \cdot b\\
# $$
#
# $$
# \frac{a}{b}= \frac{7850-13600}{1000-7850}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# Ratio_ab= (s*rho_water-rho_Hg)/(rho_water-s*rho_water)
# Out:
# \[
# \begin{aligned}
# \mathrm{Ratio}_{ab} &= \frac{ s \cdot \rho_{water} - \rho_{Hg} }{ \rho_{water} - s \cdot \rho_{water} } \\&= \frac{ 7.850 \cdot 1000 - 13600 }{ 1000 - 7.850 \cdot 1000 } \\&= 0.839  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 7 (***)

# %% [markdown]
# A concrete cube 0.5 m on each side is to be held in equilibrium underwater by attaching a light foam buoy to it. What minimum volume of foam is required? The specific weights of concrete and foam are 23.58 and 0.79 kN/m3 respectively. {0.19 m3}

# %% [markdown]
# **Given:**

# %%
# %%render param
# L= 0.5 #m
# gamma_concrete= 23.58*1000 #N/m3
# gamma_foam= 0.79*1000 #N/m3
# Out:
# \[
# \begin{aligned}
# L &= 0.500 \; \;\textrm{(m)}
#  &\gamma_{concrete} &= 23580.000 \; \;\textrm{(N/m3)}
#  &\gamma_{foam} &= 790.000 \; \;\textrm{(N/m3)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# A sum of forces in the y-axis is necesssary to determine the minimum volume of foam
#
# $$
# \sum F_y=0\\
# $$
#
# $$
# W_{foam}+W_{concrete}-F_{bfoam}-F_{bconcrete}=0\\
# $$
#
# $$
# W_{foam}=-W_{concrete}+F_{bfoam}+F_{bconcrete}\\
# $$
#
# Replacing the equation for volume $W= \rho g V$ for each material
#
# $$
# \gamma_{foam}Vol_{foam}=-\gamma_{concrete}Vol_{concrete}+\rho_{water}g Vol_{foam}+\rho_{water} g Vol_{concrete}\\
# $$
#
# $$
# Vol_{foam}(\gamma_{foam}-\rho_{water}g)=\rho_{water} g Vol_{concrete}-\gamma_{concrete}Vol_{concrete}\\
# $$
#
# $$
# Vol_{foam}=\frac{\rho_{water} g Vol_{concrete}-\gamma_{concrete}Vol_{concrete}}{\gamma_{foam}-\rho_{water}g}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# Vol_concrete= L**3 #m3
# Vol_foam= (rho_water*g*Vol_concrete-gamma_concrete*Vol_concrete)/(gamma_foam-rho_water*g) #m3
# Out:
# \[
# \begin{aligned}
# \mathrm{Vol}_{concrete} &= \left( L \right) ^{ 3 } \\&= \left( 0.500 \right) ^{ 3 } \\&= 0.125 \; \;\textrm{(m3)}\\[10pt]
# \\[10pt]
# \mathrm{Vol}_{foam} &= \frac{ \rho_{water} \cdot g \cdot \mathrm{Vol}_{concrete} - \gamma_{concrete} \cdot \mathrm{Vol}_{concrete} }{ \gamma_{foam} - \rho_{water} \cdot g } \\&= \frac{ 1000 \cdot 9.810 \cdot 0.125 - 23580.000 \cdot 0.125 }{ 790.000 - 1000 \cdot 9.810 } \\&= 0.191 \; \;\textrm{(m3)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Advanced buoyancy problems

# %% [markdown]
# ---
# #### Question 8 (***)

# %% [markdown]
# A wooden beam (s = 0.64) is 140 mm by 140 mm by 5 m and is hinged at A as shown below. At what angle will the beam float in the water? {19.5 °}

# %%
from PIL import Image
img = Image.open(r"figures/78.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=436x348 at 0x276B76B0C10>

# %% [markdown]
# **Given:**

# %%
# %%render param
# s=0.64
# L_T= 5 #m
# wide=140/1000 #m
# b=140/1000 #m
# h=1 #m
# Out:
# \[
# \begin{aligned}
# s &= 0.640 \;
#  &L_{T} &= 5 \; \;\textrm{(m)}
#  &\mathrm{wide} &= 0.140 \; \;\textrm{(m)}
# \\[10pt]
#  b &= 0.140 \; \;\textrm{(m)}
#  &h &= 1 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
#
# The angle can be calculated with the momentum equation:
#
# $$
# \sum M=0 \\
# F_b \cdot X_{F_b}- W \cdot X_{W}=0 \\
# $$
#
# Where:
#
# $$
# W=g \cdot s \cdot \rho_{water} \cdot wide\cdot b \cdot L_T\\
# $$
#
# $$
# F_b= g \cdot wide \cdot b \cdot L\\
#
# $$
# X_{F_b}= L_T - \frac {L \cdot cos \theta}{2}\\
# $$
#
# $$
# X_{W}= \frac {L_T \cdot cos \theta}{2}\\
# $$
#
#
# Replacing the forces and the distance in the equation of momentum
#
# $$
# g \cdot L \cdot wide \cdot b \cdot L_T - \frac {L \cdot cos \theta}{2}- W\frac {L_T \cdot cos \theta}{2} =0 \\
# $$
#
# Then we can solve L.
#
# The angle can be calculated as:
#
# $$
# \theta=arcsin(\frac {h}{L_t-L})
# $$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# W= g*s*rho_water*wide*b*L_T #N
# Out:
# \[
# \begin{aligned}
# W &= g \cdot s \cdot \rho_{water} \cdot \mathrm{wide} \cdot b \cdot L_{T} \\&= 9.810 \cdot 0.640 \cdot 1000 \cdot 0.140 \cdot 0.140 \cdot 5 \\&= 615.283 \; \;\textrm{(N)}\\[10pt]
# \end{aligned}
# \]

# %%
from sympy.solvers import solve
from sympy import Symbol

L = Symbol("L")
ans= solve(rho_water*g*wide*b*L*(L_T-L/2)-W*L_T/2,L)
L_=round(ans[0],1)
print("L: ",L_, "m")
# Out:
# L:  2.00000000000000 m

# %%
# %%render long 2
# theta=degrees(asin (h/(L_T-L_))) #°
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14176/3116127843.py in <module>
# ----> 1 theta=degrees(asin (h/(L_T-L_))) #°
#
# NameError: name 'L_T' is not defined

# %% [markdown]
# ---
# #### Question 9 (***)[R]

# %% [markdown]
# Calculate the hydrostatic force and its line of action on a semi-cylindrical indentation ABC per unit width in the figure below. {115 kN at 10.6° above the horizontal}

# %%
img = Image.open(r"figures/79.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=232x262 at 0x1D0C24DCD00>

# %% [markdown]
# **Given:**

# %%
# %%render param
# s=0.88
# h_1=2 #m
# h_2=2 #m
# h_3=2.5 #m
# h_4=1 #m
# B=1#m
# Out:
# \[
# \begin{aligned}
# s &= 0.880 \;
#  &h_{1} &= 2 \; \;\textrm{(m)}
#  &h_{2} &= 2 \; \;\textrm{(m)}
# \\[10pt]
#  h_{3} &= 2.500 \; \;\textrm{(m)}
#  &h_{4} &= 1 \; \;\textrm{(m)}
#  &B &= 1 \; \;\textrm{(m)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint Horizontal Force**

# %% [markdown]
# ```{toggle}
# To calculate the  hydrostatic force, the following equations should be used:
#
# $$
# F= \sqrt {F_H^2+F_V^2}
# $$
#
# The horizontal force is calculated in the vertical projection of the semi-cylindrical indendation ABC.
#
# $$
# F_H= \rho \cdot g \cdot  h_c  \cdot A_{projection}\\
# $$
#
# $$
# A= b \cdot  h_{projection}\\
# $$
#
# $$
# I_c= \frac {b \cdot h^3}{12}\\
# $$
#
# $$
# y_p= y_c + \frac {I_c}{y_cA}
# $$
# ```

# %% [markdown]
# **Solution Horizontal Force**

# %%
# %%render long 2
# rho= s*rho_water #kg/m3
# F_H= rho*g*(h_1+h_2+h_3/2)*(h_3*1) #N
# y_c= h_1+h_2+h_3/2 #m
# I_c= B*h_3**3/12 #m4
# A= B*h_3 #m2
# y_p= y_c+ I_c/(y_c*A)#m
# Out:
# \[
# \begin{aligned}
# \rho &= s \cdot \rho_{water} \\&= 0.880 \cdot 1000 \\&= 880.000 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# F_{H} &= \rho \cdot g \cdot \left( h_{1} + h_{2} + \frac{ h_{3} }{ 2 } \right) \cdot \left( h_{3} \cdot 1 \right) \\&= 880.000 \cdot 9.810 \cdot \left( 2 + 2 + \frac{ 2.500 }{ 2 } \right) \cdot \left( 2.500 \cdot 1 \right) \\&= 113305.500 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# y_{c} &= h_{1} + h_{2} + \frac{ h_{3} }{ 2 } \\&= 2 + 2 + \frac{ 2.500 }{ 2 } \\&= 5.250 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# I_{c} &= B \cdot \frac{ \left( h_{3} \right) ^{ 3 } }{ 12 } \\&= 1 \cdot \frac{ \left( 2.500 \right) ^{ 3 } }{ 12 } \\&= 1.302 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# A &= B \cdot h_{3} \\&= 1 \cdot 2.500 \\&= 2.500 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# y_{p} &= y_{c} + \frac{ I_{c} }{ y_{c} \cdot A } \\&= 5.250 + \frac{ 1.302 }{ 5.250 \cdot 2.500 } \\&= 5.349 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint Vertical Force**

# %% [markdown]
# ```{toggle}
# The vertical force acting on any area is equal to the weight of the volume of liquid above it,for that reason, the following equations can be used.
#
# $F_V$ = Weight of fluid above the panel
#
# $$
# F_V= \rho g Vol
# $$
#
# The centroid of a semi-circle is
#
# $$
# X= \frac {4r}{3\pi}
# $$
# ```

# %% [markdown]
# **Solution Vertical and Total Force**

# %%
# %%render long 2
# F_V= rho*g*((pi*(h_3/2)**2)*1)/2 #N
# X= (4*2.5/2)/(3*pi) #m
# F= sqrt(F_H**2+F_V**2) #N
# theta= degrees(atan(F_V/F_H)) #°
# Out:
# \[
# \begin{aligned}
# F_{V} &= \rho \cdot g \cdot \frac{ \left( \pi \cdot \left( \frac{ h_{3} }{ 2 } \right) ^{ 2 } \right) \cdot 1 }{ 2 } \\&= 880.000 \cdot 9.810 \cdot \frac{ \left( 3.142 \cdot \left( \frac{ 2.500 }{ 2 } \right) ^{ 2 } \right) \cdot 1 }{ 2 } \\&= 21188.079 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# X &= \frac{ 4 \cdot \frac{ 2.5 }{ 2 } }{ 3 \cdot \pi } \\&= \frac{ 4 \cdot \frac{ 2.5 }{ 2 } }{ 3 \cdot 3.142 } \\&= 0.531 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# F &= \sqrt { \left( F_{H} \right) ^{ 2 } + \left( F_{V} \right) ^{ 2 } } \\&= \sqrt { \left( 113305.500 \right) ^{ 2 } + \left( 21188.079 \right) ^{ 2 } } \\&= 115269.558 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# \theta &= \operatorname{degrees} { \left( \arctan \left( \frac{ F_{V} }{ F_{H} } \right) \right) } \\&= \operatorname{degrees} { \left( \arctan \left( \frac{ 21188.079 }{ 113305.500 } \right) \right) } \\&= 10.592 \; \;\textrm{(°)}\\[10pt]
# \end{aligned}
# \]

# %%
img = Image.open(r"figures/79s.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=540x238 at 0x1D0C226E340>

# %% [markdown]
# ---
# #### Question 10 (***)

# %% [markdown]
# A radial gate is used to seal an opening at the bottom of a dam wall as shown below. The gate is 3 m wide into the page. It has a hinge at O allowing it to be opened by applying a force F as shown. Calculate the size of the buoyancy force on the radial gate. {140.8 kN}

# %%
from PIL import Image
img = Image.open(r"figures/80.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=423x242 at 0x276B77142B0>

# %% [markdown]
# **Given:**

# %%
# %%render param
# B= 3 #m
# r= 1#m
# h_water= 4 #m
# Out:
# \[
# \begin{aligned}
# B &= 3 \; \;\textrm{(m)}
#  &r &= 1 \; \;\textrm{(m)}
#  &h_{water} &= 4 \; \;\textrm{(m)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The buoyancy force is:
#
# $$F_b=\rho_{water} \cdot g \cdot A \cdot B\\
# A= h_{water} \cdot r+ \frac{\pi r^2}{4}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# F_b= rho_water*g*((h_water*r+(pi*r**2)/4))*B/1000 #kN
# Out:
# \[
# \begin{aligned}
# F_{b} &= \rho_{water} \cdot g \cdot \left( h_{water} \cdot r + \frac{ \pi \cdot \left( r \right) ^{ 2 } }{ 4 } \right) \cdot \frac{ B }{ 1000 } \\&= 1000 \cdot 9.8 \cdot \left( 4 \cdot 1 + \frac{ 3.1 \cdot \left( 1 \right) ^{ 2 } }{ 4 } \right) \cdot \frac{ 3 }{ 1000 } \\&= 140.8 \; \;\textrm{(kN)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 11 (* - ***)

# %% [markdown]
# A container with cross-section below is filled with water. The container has a width of 5 m into the page. The radius r of the quarter-cylindrical section AB is 2 m. Do the following for the quarter-cylindrical panel AB:
# a) * Calculate the pressure at A and B and draw the pressure distribution on the panel. {19.62 kPa}
# b) ** Calculate the size of the horizontal hydrostatic force. {98.1 kPa}
# c) ** Use the moment of area method to show that the horizontal force in (b) acts (2/3)r below the surface of the water.  {1.333 m = 2/3r}
# d) ** Calculate the size and line of action of the vertical hydrostatic force. {154kN upwards, 0.849 m left of O}
# e) ** Determine the size and direction of the resultant hydrostatic force. {183 kN, 57.5° above the horizontal}
# f) *** Show that the resultant hydrostatic force acts through point O.

# %%
img = Image.open(r"figures/81.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=455x323 at 0x1D0C23AA880>

# %%
# %%render param
# B= 5 #m
# r= 2 #m
# Out:
# \[
# \begin{aligned}
# B &= 5 \; \;\textrm{(m)}
#  &r &= 2 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# In A, atmosferic gauge pressure:
#
# $$
# p_A=0
# $$
#
# The pressure in B can be calculated using:
#
# $$
# p_B= \rho g h
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_B= rho_water*g*r/1000 #kPa
# Out:
# \[
# \begin{aligned}
# p_{B} &= \rho_{water} \cdot g \cdot \frac{ r }{ 1000 } \\&= 1000 \cdot 9.81 \cdot \frac{ 2 }{ 1000 } \\&= 19.62 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %%
img = Image.open(r"figures/81s.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=281x205 at 0x21F15BD6AF0>

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The horizontal force is calculated in the vertical projection
#
# $$
# F_H= \rho \cdot  g \cdot  h_c \cdot A_{projection}\\
# A= b \cdot  h_{projection}\\
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# h_c= r/2 #m
# A= r*B #m2
# F_H= rho_water*g*h_c*A/1000 #kN
# Out:
# \[
# \begin{aligned}
# h_{c} &= \frac{ r }{ 2 } \\&= \frac{ 2 }{ 2 } \\&= 1.0 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= r \cdot B \\&= 2 \cdot 5 \\&= 10 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F_{H} &= \rho_{water} \cdot g \cdot h_{c} \cdot \frac{ A }{ 1000 } \\&= 1000 \cdot 9.8 \cdot 1.0 \cdot \frac{ 10 }{ 1000 } \\&= 98.1 \; \;\textrm{(kN)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# c)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The moment of area is the following equation
#
# $$
# I_c= \frac {bh^3}{12}\\
# $$
#
# $$
# y_p= y_c + \frac {I_c}{y_cA}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# I_c= B*r**3/12 #m4
# y_p= (A*h_c**2+I_c)/(A*h_c) #m from top of the panel
# Out:
# \[
# \begin{aligned}
# I_{c} &= B \cdot \frac{ \left( r \right) ^{ 3 } }{ 12 } \\&= 5 \cdot \frac{ \left( 2 \right) ^{ 3 } }{ 12 } \\&= 3.33 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p} &= \frac{ A \cdot \left( h_{c} \right) ^{ 2 } + I_{c} }{ A \cdot h_{c} } \\&= \frac{ 10 \cdot \left( 1.00 \right) ^{ 2 } + 3.33 }{ 10 \cdot 1.00 } \\&= 1.33 \; \;\textrm{(m from top of the panel)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# $$
# \frac{2r}{3}=\frac{4}{3}=1.333
# $$

# %% [markdown]
# d)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The vertical force acting on any area is equal to the weight of the volume of liquid above it,for that reason, the following equations can be used.
#
# $F_V$ = Weight of fluid above the panel
#
# $$
# F_V= \rho g Vol\\
# $$
#
# The line of action is the centroid of the figure
#
# $$
# X= \frac {4r}{3\pi}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# F_V= rho_water*g*(pi*r**2)/4*B/1000 #kN
# X= (4*r)/(3*pi) #m
# Out:
# \[
# \begin{aligned}
# F_{V} &= \rho_{water} \cdot g \cdot \frac{ \pi \cdot \left( r \right) ^{ 2 } }{ 4 } \cdot \frac{ B }{ 1000 } \\&= 1000 \cdot 9.81 \cdot \frac{ 3.14 \cdot \left( 2 \right) ^{ 2 } }{ 4 } \cdot \frac{ 5 }{ 1000 } \\&= 154.10 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# X &= \frac{ 4 \cdot r }{ 3 \cdot \pi } \\&= \frac{ 4 \cdot 2 }{ 3 \cdot 3.14 } \\&= 0.85 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# e)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The size and line of action of the resultant force can be calculated as:
#
# $$
# F_r=\sqrt{F_x^2+F_y^2}\\
# tan\theta = \frac {F_x}{F_y}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# F= sqrt(F_H**2+F_V**2) #kN
# theta= degrees(atan(F_V/F_H)) #°
# Out:
# \[
# \begin{aligned}
# F &= \sqrt { \left( F_{H} \right) ^{ 2 } + \left( F_{V} \right) ^{ 2 } } \\&= \sqrt { \left( 98.10 \right) ^{ 2 } + \left( 154.10 \right) ^{ 2 } } \\&= 182.67 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# \theta &= \operatorname{degrees} { \left( \arctan \left( \frac{ F_{V} }{ F_{H} } \right) \right) } \\&= \operatorname{degrees} { \left( \arctan \left( \frac{ 154.10 }{ 98.10 } \right) \right) } \\&= 57.52 \; \;\textrm{(°)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# f)

# %% [markdown]
# **Hint**

# %%
img = Image.open(r"figures/81s2.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=338x244 at 0x21F15E23190>

# %% [markdown]
# ```{toggle}
# To show that the resultant hydrostatic force acts perpendicularly on the curved panel is necessary to calculate the angle between O and A (in the figure above).
#
# This angle can be calculated with the following equation
#
# $$
# tan\theta = \frac {X_O}{Y_O}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# beta= degrees(atan(Y_p/X)) #°
# Out:
# \[
# \begin{aligned}
# \beta &= \operatorname{degrees} { \left( \arctan \left( \frac{ Y_{p} }{ X } \right) \right) } \\&= \operatorname{degrees} { \left( \arctan \left( \frac{ 1.33 }{ 0.85 } \right) \right) } \\&= 57.52 \; \;\textrm{(°)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ```{toggle}
# $$
# \beta = \theta\\
# $$
#
# Thus F goes through point O
# ```

# %% [markdown]
# ---
# #### Question 12 (***)

# %% [markdown]
# A glass tube with an internal diameter of 5 mm is inserted into a container filled with mercury. Calculate the depression in the mercury level inside the tube due to capillary forces. Assume a contact angle of 135° between the mercury and the glass. {2.16 mm}

# %% [markdown]
# **Given:**

# %%
# %%render param
# d=5 #mm
# angle= 135 #°
# d_m=d/1000 #m
# Out:
# \[
# \begin{aligned}
# d &= 5 \; \;\textrm{(mm)}
#  &\mathrm{angle} &= 135 \; \;\textrm{(°)}
#  &d_{m} &= 0.005 \; \;\textrm{(m)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
#
# Using Table A.4 is possible to define the surface tension $\sigma=0.51 N/m$
#
# $$
# \sum F=0\\
# $$
#
# $$
# F_b -F_{\sigma}=0\\
# $$
#
# $$
# F_b= \frac {\rho g \pi d^2 h }{4}\\
# $$
#
# $$
# F_{\sigma}= \pi d \sigma cos \theta\\
# $$
#
# $$
# \frac {\rho g \pi d^2 h }{4}-\pi d \sigma cos \theta=0\\
# $$
#
# $$
# h= \frac {4\sigma cos \theta}{\rho gd}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# sigma= 0.51 #N/m
# theta=180-angle #°
# theta_rad=(radians(theta)) #radians
# h=(4*sigma*cos (theta_rad))/(rho_Hg*g*d_m) #m
# Out:
# \[
# \begin{aligned}
# \sigma &= 0.510 \; \;\textrm{(N/m)}
# \\[10pt]
# \theta &= 45 \; \;\textrm{(°)}
# \\[10pt]
# \theta_{rad} &= 0.785 \; \;\textrm{(radians)}
# \\[10pt]
# h &= \frac{ 4 \cdot \sigma \cdot \cos \left( \theta_{rad} \right) }{ \rho_{Hg} \cdot g \cdot d_{m} } \\&= \frac{ 4 \cdot 0.510 \cdot \cos \left( 0.785 \right) }{ 13600 \cdot 9.810 \cdot 0.005 } \\&= 0.002 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 13 (** - ****)

# %% [markdown]
# A water tank has a quarter-circular panel in one corner as shown in the figure below.
#
# a.**Calculate the size and line of action of the horizontal hydrostatic force on the panel. {309 kN at 4.519 m below the water surface}
#
# b.***Calculate the size of the vertical force on the panel. {289 kN}
#
# c.****Calculate the line of action of the vertical force on the panel {0.514 m left of side panel}.
#
# d.****Calculate the size and line of action of the resultant hydrostatic force on the panel. {423 kN at 43.1° below the horizontal}

# %% [markdown]
# **Given:**

# %%
from PIL import Image
img = Image.open(r"figures/83.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=140x122 at 0x1D0C2316BE0>

# %%
# %%render param
# B= 7 #m
# r= 1#m
# h_water= 4 #m
# Out:
# \[
# \begin{aligned}
# B &= 7 \; \;\textrm{(m)}
#  &r &= 1 \; \;\textrm{(m)}
#  &h_{water} &= 4 \; \;\textrm{(m)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# To calculate the  hydrostatic force, the following equations should be used:
#
# $$
# F= \sqrt {F_H^2+F_V^2}
# $$
#
# The horizontal force is calculated in the vertical projection of the semi-cylindrical indendation ABC.
#
# $$
# F_H= \rho g h_c A_{projection}\\
# $$
#
# $$
# A= bh_{projection}\\
# $$
#
# $$
# I_c= \frac {bh^3}{12}\\
# $$
#
# $$
# y_p= y_c + \frac {I_c}{y_cA}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h_c= h_water+r/2 #m
# A= B*r #m2
# F_H= rho_water*g*h_c*A/1000 #kN
# I_c= B*r**3/12 #m4
#
# y_p= h_c+I_c/(h_c*A) #m
# Out:
# \[
# \begin{aligned}
# h_{c} &= h_{water} + \frac{ r }{ 2 } \\&= 4 + \frac{ 1 }{ 2 } \\&= 4.50 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= B \cdot r \\&= 7 \cdot 1 \\&= 7 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F_{H} &= \rho_{water} \cdot g \cdot h_{c} \cdot \frac{ A }{ 1000 } \\&= 1000 \cdot 9.81 \cdot 4.50 \cdot \frac{ 7 }{ 1000 } \\&= 309.01 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# I_{c} &= B \cdot \frac{ \left( r \right) ^{ 3 } }{ 12 } \\&= 7 \cdot \frac{ \left( 1 \right) ^{ 3 } }{ 12 } \\&= 0.58 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p} &= h_{c} + \frac{ I_{c} }{ h_{c} \cdot A } \\&= 4.50 + \frac{ 0.58 }{ 4.50 \cdot 7 } \\&= 4.52 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The vertical force acting on any area is equal to the weight of the volume of liquid above it,for that reason, the following equations can be used.
#
# $F_y$ = Weight of fluid above the panel
#
# $$
# F_V= \rho g Vol
# $$
#
# $$
# W=\rho g [(h_{water}+r)r-\frac {\pi r^2}{4}]*B\\
# $$
#
# $$
# F_W= \rho g (h_{water}+r) r *B\\
# $$
#
# $$
# F_B= \rho g \frac {\pi r^2}{4}*B
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# F_W= rho_water*g*(h_water+r)*r*B/1000#kN
# F_B= rho_water*g*pi*r**2*B/4/1000 #kN
# F_V= F_W-F_B #kN
# Out:
# \[
# \begin{aligned}
# F_{W} &= \rho_{water} \cdot g \cdot \left( h_{water} + r \right) \cdot r \cdot \frac{ B }{ 1000 } \\&= 1000 \cdot 9.8 \cdot \left( 4 + 1 \right) \cdot 1 \cdot \frac{ 7 }{ 1000 } \\&= 343.4 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# F_{B} &= \rho_{water} \cdot g \cdot \pi \cdot \left( r \right) ^{ 2 } \cdot \frac{ B }{ 4 } \cdot \frac{1} { 1000 } \\&= 1000 \cdot 9.8 \cdot 3.1 \cdot \left( 1 \right) ^{ 2 } \cdot \frac{ 7 }{ 4 } \cdot \frac{1} { 1000 } \\&= 53.9 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# F_{V} &= F_{W} - F_{B} \\&= 343.4 - 53.9 \\&= 289.4 \; \;\textrm{(kN)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# c)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# To calculate the line of action is necessary to use the moment equation
#
# $$
# F_V\bar X= F_{B} \bar X_{B}- F_{w} \bar X_{w}
# $$
#
# Where:
#
# $ F_W $ is acting in the middle from O
#
#
# $F_V$ is acting at $ X= \frac{4r}{3\pi}$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
#
# X_W= r/2 #m
# X_B = 4*r/(3*pi) #m
# X= (F_W*X_W -F_B*X_B)/ F_V #m
# Out:
# \[
# \begin{aligned}
# X_{W} &= \frac{ r }{ 2 } \\&= \frac{ 1 }{ 2 } \\&= 0.500 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# X_{B} &= 4 \cdot \frac{ r }{ 3 \cdot \pi } \\&= 4 \cdot \frac{ 1 }{ 3 \cdot 3.142 } \\&= 0.424 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# X &= \frac{ F_{W} \cdot X_{W} - F_{B} \cdot X_{B} }{ F_{V} } \\&= \frac{ 343350.000 \cdot 0.500 - 53933.292 \cdot 0.424 }{ 289416.708 } \\&= 0.514 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# d)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The size and line of action of the resultant force can be calculated as:
#
# $$
# F_R= \sqrt {F_H^2+F_V^2}\\
# tan\theta= \frac {F_V}{F_H}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# F_R= sqrt(F_H**2+F_V**2) #kN
# theta= degrees(atan(F_V/F_H)) #°
# Out:
# \[
# \begin{aligned}
# F_{R} &= \sqrt { \left( F_{H} \right) ^{ 2 } + \left( F_{V} \right) ^{ 2 } } \\&= \sqrt { \left( 309.0 \right) ^{ 2 } + \left( 289.4 \right) ^{ 2 } } \\&= 423.4 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# \theta &= \operatorname{degrees} { \left( \arctan \left( \frac{ F_{V} }{ F_{H} } \right) \right) } \\&= \operatorname{degrees} { \left( \arctan \left( \frac{ 289.4 }{ 309.0 } \right) \right) } \\&= 43.1 \; \;\textrm{(°)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 14 (** - ****)

# %% [markdown]
# A radial gate is used to seal an opening at the bottom of a dam wall as shown below. The gate is 3 m wide into the page. It has a hinge at O allowing it to be opened by applying a force F as shown. Do the following:
#
# a.	**Calculate the size and line of action of the horizontal hydrostatic force on the gate. {132.4 kN 4.519 m below the surface}
#
# b.	***Calculate the size of the vertical hydrostatic force on the gate. {140.8 kN}
#
# c.	****Calculate the line of action of the vertical hydrostatic force on the gate. {0.488 m left of OC}
#
# d.	****Calculate the size and line of action of the resultant hydrostatic force on the gate. {193.3 kN acting at 46.8° above the horizontal}
#
# e.	****Show that the hydrostatic force acts through the hinge O.
#
# f.	****What does this mean for the size of force required to open the gate?
#
# g.	How could you have known the answer for (c) without calculating the resultant hydrostatic force?

# %%
from PIL import Image
img = Image.open(r"figures/84.png")
img= img.resize((500,300))
img
# Out:
# <PIL.Image.Image image mode=RGBA size=500x300>

# %% [markdown]
# **Given:**

# %%
# %%render param
# B= 3 #m
# r= 1#m
# h_water= 4 #m
# Out:
# \[
# \begin{aligned}
# B &= 3 \; \;\textrm{(m)}
#  &r &= 1 \; \;\textrm{(m)}
#  &h_{water} &= 4 \; \;\textrm{(m)}
# \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# a)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The size of the horizontal hydrostatic force can be calculated using the following equations:
#
# $$
# F_H= \rho g h_c A_{projection}\\
# $$
#
# $$
# A= bh_{projection}\\
# $$
#
# and the line of action of this force can be calculated with:
#
# $$
# I_c= \frac {bh^3}{12}\\
# $$
#
# $$
# y_p= y_c + \frac {I_c}{y_cA}
# $$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# h_c= h_water+r/2 #m
# A= B*r #m2
# F_H= rho_water*g*h_c*A/1000 #kN
# I_c= B*r**3/12 #m4
#
# y_p= h_c+I_c/(h_c*A) #m
# Out:
# \[
# \begin{aligned}
# h_{c} &= h_{water} + \frac{ r }{ 2 } \\&= 4 + \frac{ 1 }{ 2 } \\&= 4.500 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= B \cdot r \\&= 3 \cdot 1 \\&= 3 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# F_{H} &= \rho_{water} \cdot g \cdot h_{c} \cdot \frac{ A }{ 1000 } \\&= 1000 \cdot 9.810 \cdot 4.500 \cdot \frac{ 3 }{ 1000 } \\&= 132.435 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# I_{c} &= B \cdot \frac{ \left( r \right) ^{ 3 } }{ 12 } \\&= 3 \cdot \frac{ \left( 1 \right) ^{ 3 } }{ 12 } \\&= 0.250 \; \;\textrm{(m4)}\\[10pt]
# \\[10pt]
# y_{p} &= h_{c} + \frac{ I_{c} }{ h_{c} \cdot A } \\&= 4.500 + \frac{ 0.250 }{ 4.500 \cdot 3 } \\&= 4.519 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# b)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The vertical force acting on any area is equal to the weight of the volume of liquid above it,for that reason, the following equations can be used:
#
# $F_y$ = Weight of fluid above the panel
#
# $$
# F_V= \rho g Vol
# $$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# V= h_water*r*B + pi*r**2*B/4 #m3
# F_v= rho_water*g*V/1000 #N
# Out:
# \[
# \begin{aligned}
# V &= h_{water} \cdot r \cdot B + \pi \cdot \left( r \right) ^{ 2 } \cdot \frac{ B }{ 4 } \\&= 4 \cdot 1 \cdot 3 + 3.1 \cdot \left( 1 \right) ^{ 2 } \cdot \frac{ 3 }{ 4 } \\&= 14.4 \; \;\textrm{(m3)}\\[10pt]
# \\[10pt]
# F_{v} &= \rho_{water} \cdot g \cdot \frac{ V }{ 1000 } \\&= 1000 \cdot 9.8 \cdot \frac{ 14.4 }{ 1000 } \\&= 140.8 \; \;\textrm{(N)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# c)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# To calculate the line of action is necessary to use the moment equation
#
# $$
# W_{total}\bar X= W_{rect} \bar X_{rect}+ W_{circle} \bar X_{circle}
# $$
#
# Where:
#
# $ \bar X_{rect} $ is acting in $r/2$
#
#
# $ \bar X_{circle}$ is acting at $ X= \frac{4r}{3\pi}$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# X_circle = 4*r/(3*pi) #m
# X_rect= r/2 #m
# W_circle= rho_water*g*pi*r**2*B/4 #N
# W_rect= rho_water*g*B*r*h_water #N
# X= (W_circle*X_circle+W_rect*X_rect)/(W_circle+W_rect)#m
# Out:
# \[
# \begin{aligned}
# X_{circle} &= 4 \cdot \frac{ r }{ 3 \cdot \pi } \\&= 4 \cdot \frac{ 1 }{ 3 \cdot 3.142 } \\&= 0.424 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# X_{rect} &= \frac{ r }{ 2 } \\&= \frac{ 1 }{ 2 } \\&= 0.500 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# W_{circle} &= \rho_{water} \cdot g \cdot \pi \cdot \left( r \right) ^{ 2 } \cdot \frac{ B }{ 4 } \\&= 1000 \cdot 9.810 \cdot 3.142 \cdot \left( 1 \right) ^{ 2 } \cdot \frac{ 3 }{ 4 } \\&= 23114.268 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# W_{rect} &= \rho_{water} \cdot g \cdot B \cdot r \cdot h_{water} \\&= 1000 \cdot 9.810 \cdot 3 \cdot 1 \cdot 4 \\&= 117720.000 \; \;\textrm{(N)}\\[10pt]
# \\[10pt]
# X &= \frac{ W_{circle} \cdot X_{circle} + W_{rect} \cdot X_{rect} }{ W_{circle} + W_{rect} } \\&= \frac{ 23114.268 \cdot 0.424 + 117720.000 \cdot 0.500 }{ 23114.268 + 117720.000 } \\&= 0.488 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# d)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# The size of the resultant hydrostatic force can be calculated as:
#
# $$
# F_R= \sqrt {F_H^2+F_V^2}
# $$
#
# and the line of action of the resultant force is:
#
# $$
# \theta=arctan( \frac {F_v}{F_H})
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# F_R= sqrt(F_H**2+F_v**2) #kN
# theta= degrees(atan(F_v/F_H)) #°
# Out:
# \[
# \begin{aligned}
# F_{R} &= \sqrt { \left( F_{H} \right) ^{ 2 } + \left( F_{v} \right) ^{ 2 } } \\&= \sqrt { \left( 132.44 \right) ^{ 2 } + \left( 140.83 \right) ^{ 2 } } \\&= 193.32 \; \;\textrm{(kN)}\\[10pt]
# \\[10pt]
# \theta &= \operatorname{degrees} { \left( \arctan \left( \frac{ F_{v} }{ F_{H} } \right) \right) } \\&= \operatorname{degrees} { \left( \arctan \left( \frac{ 140.83 }{ 132.44 } \right) \right) } \\&= 46.76 \; \;\textrm{(°)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# e)

# %% [markdown]
# **Hint**

# %% [markdown]
# ```{toggle}
# To show that the hydrostatic force acts trough the hinge O, we need to show that the line between the force's point of action and hinge O has the same angle as the resultant force. Theformer can be calculated as follows:
#
# $$
# \alpha=arctan(\frac{y_p-h_{water}}{X})
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# alpha= degrees(atan((y_p-h_water)/X))#°
# Out:
# \[
# \begin{aligned}
# \alpha &= \operatorname{degrees} { \left( \arctan \left( \frac{ y_{p} - h_{water} }{ X } \right) \right) } \\&= \operatorname{degrees} { \left( \arctan \left( \frac{ 4.52 - 4 }{ 0.49 } \right) \right) } \\&= 46.76 \; \;\textrm{(°)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ```{toggle}
# The angles are igual, for that reason the force acts through O.
# ```

# %% [markdown]
# f)

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{toggle}
# The size of force required to open the gate is only determined by the weight of the gate. Hydrostatic force does not contribute as it acts through hinge O.
# ```

# %% [markdown]
# g)

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{toggle}
# Pressure vectors all act through O.
# ```

# %%
from PIL import Image
img = Image.open(r"figures/84s.png")
img= img.resize((500,300))
img
# Out:
# <PIL.Image.Image image mode=RGBA size=500x300>
